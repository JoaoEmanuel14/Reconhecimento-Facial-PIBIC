# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoEmanuel14/Reconhecimento-Facial-SCface/blob/main/Modelo_SCface_Joao_Emanuel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reconhecimento Facial em Câmeras de Segurança aplicado em Cidades Inteligentes e Segurança Pública
#
# Este notebook apresenta o processo de construção de um modelo de **reconhecimento facial** baseado no *dataset* *SCface*.
#
# Neste notebook, estão presentes as etapas de:
# - 1. Preparação do conjunto de dados
# - 2. Detecção facial com *MTCNN*
# - 3. Extração de características com *FaceNet e ArcFace*
# - 4. Identificação facial através da comparação de *embeddings*

# %% [markdown]
# # 0. Importando bibliotecas e dependências, além de fazer device-agnostic code

# %%
# !nvidia-smi
# Out:
# Wed Aug 13 13:38:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   28C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Montar Google Colab para ter acesso ao dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Instalando bibliotecas necessárias
# !pip install facenet-pytorch --no-deps
# !pip install -U albumentationsx
# !pip install torchvision
# Out:
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.6.0-py3-none-any.whl.metadata (12 kB)
# Downloading facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.6 MB/s eta 0:00:00
# Installing collected packages: facenet-pytorch
# Successfully installed facenet-pytorch-2.6.0
# Collecting albumentationsx
#   Downloading albumentationsx-2.0.9-py3-none-any.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentationsx) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentationsx) (1.16.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentationsx) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentationsx) (2.11.7)
# Collecting albucore==0.0.33 (from albumentationsx)
#   Downloading albucore-0.0.33-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentationsx) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.33->albumentationsx) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.33->albumentationsx) (6.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentationsx) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentationsx) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentationsx) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentationsx) (0.4.1)
# Downloading albumentationsx-2.0.9-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 17.3 MB/s eta 0:00:00
# Downloading albucore-0.0.33-py3-none-any.whl (18 kB)
# Installing collected packages: albucore, albumentationsx
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.24
#     Uninstalling albucore-0.0.24:
#       Successfully uninstalled albucore-0.0.24
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 2.0.8 requires albucore==0.0.24, but you have albucore 0.0.33 which is incompatible.
# Successfully installed albucore-0.0.33 albumentationsx-2.0.9
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.6.0+cu124)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->torchvision)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->torchvision)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.6.0->torchvision)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->torchvision)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchvision) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 99.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 109.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127

# %%
# Configurando o repositório do CodeFormer
# !rm -rf CodeFormer # Remove a pasta antiga se existir
# !git clone https://github.com/sczhou/CodeFormer
# %cd CodeFormer

# Instalando dependencias
# !pip install -r requirements.txt
# !python basicsr/setup.py develop

# Baixando modelos pré-treinados
# !python scripts/download_pretrained_models.py facelib
# !python scripts/download_pretrained_models.py CodeFormer

# %cd ..
# Out:
# Cloning into 'CodeFormer'...
# remote: Enumerating objects: 614, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 614 (delta 203), reused 176 (delta 176), pack-reused 321 (from 2)
# Receiving objects: 100% (614/614), 17.31 MiB | 18.00 MiB/s, done.
# Resolving deltas: 100% (297/297), done.
# /content/CodeFormer
# Collecting addict (from -r requirements.txt (line 1))
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.0.0)
# Collecting lmdb (from -r requirements.txt (line 3))
#   Downloading lmdb-1.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (4.12.0.88)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.16.1)
# Collecting tb-nightly (from -r requirements.txt (line 11))
#   Downloading tb_nightly-2.21.0a20250813-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (0.21.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (4.67.1)
# Collecting yapf (from -r requirements.txt (line 15))
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.7 MB/s eta 0:00:00
# Collecting lpips (from -r requirements.txt (line 16))
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 8)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 8)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 8)) (2025.8.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r requirements.txt (line 9)) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r requirements.txt (line 9)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r requirements.txt (line 9)) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r requirements.txt (line 9)) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->-r requirements.txt (line 11)) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->-r requirements.txt (line 11)) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->-r requirements.txt (line 11)) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->-r requirements.txt (line 11)) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->-r requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->-r requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (4.14.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.1->-r requirements.txt (line 12)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.7.1->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->-r requirements.txt (line 15)) (4.3.8)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->-r requirements.txt (line 17)) (4.13.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tb-nightly->-r requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->-r requirements.txt (line 17)) (2.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->-r requirements.txt (line 17)) (1.7.1)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading lmdb-1.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.6/299.6 kB 12.0 MB/s eta 0:00:00
# Downloading tb_nightly-2.21.0a20250813-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 105.2 MB/s eta 0:00:00
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 24.6 MB/s eta 0:00:00
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: lmdb, addict, yapf, tb-nightly, lpips
# Successfully installed addict-2.4.0 lmdb-1.7.3 lpips-0.1.4 tb-nightly-2.21.0a20250813 yapf-0.43.0
# /usr/local/lib/python3.11/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running develop
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running egg_info
# creating basicsr.egg-info
# writing basicsr.egg-info/PKG-INFO
# writing dependency_links to basicsr.egg-info/dependency_links.txt
# writing requirements to basicsr.egg-info/requires.txt
# writing top-level names to basicsr.egg-info/top_level.txt
# writing manifest file 'basicsr.egg-info/SOURCES.txt'
# reading manifest file 'basicsr.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'basicsr.egg-info/SOURCES.txt'
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:529: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running build_ext
# Creating /usr/local/lib/python3.11/dist-packages/basicsr.egg-link (link to .)
# Adding basicsr 1.3.2 to easy-install.pth file
#
# Installed /content/CodeFormer
# Processing dependencies for basicsr==1.3.2
# Searching for gdown==5.2.0
# Best match: gdown 5.2.0
# Adding gdown 5.2.0 to easy-install.pth file
# Installing gdown script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for lpips==0.1.4
# Best match: lpips 0.1.4
# Adding lpips 0.1.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for yapf==0.43.0
# Best match: yapf 0.43.0
# Adding yapf 0.43.0 to easy-install.pth file
# Installing yapf script to /usr/local/bin
# Installing yapf-diff script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for tqdm==4.67.1
# Best match: tqdm 4.67.1
# Adding tqdm 4.67.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for torchvision==0.21.0+cu124
# Best match: torchvision 0.21.0+cu124
# Adding torchvision 0.21.0+cu124 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for torch==2.6.0+cu124
# Best match: torch 2.6.0+cu124
# Adding torch 2.6.0+cu124 to easy-install.pth file
# Installing torchfrtrace script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for tb-nightly==2.21.0a20250813
# Best match: tb-nightly 2.21.0a20250813
# Adding tb-nightly 2.21.0a20250813 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for scipy==1.16.1
# Best match: scipy 1.16.1
# Adding scipy 1.16.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for scikit-image==0.25.2
# Best match: scikit-image 0.25.2
# Adding scikit-image 0.25.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for requests==2.32.3
# Best match: requests 2.32.3
# Adding requests 2.32.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for PyYAML==6.0.2
# Best match: PyYAML 6.0.2
# Adding PyYAML 6.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for pillow==11.3.0
# Best match: pillow 11.3.0
# Adding pillow 11.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for opencv-python==4.12.0.88
# Best match: opencv-python 4.12.0.88
# Adding opencv-python 4.12.0.88 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for numpy==2.0.2
# Best match: numpy 2.0.2
# Adding numpy 2.0.2 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing numpy-config script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for lmdb==1.7.3
# Best match: lmdb 1.7.3
# Adding lmdb 1.7.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for future==1.0.0
# Best match: future 1.0.0
# Adding future 1.0.0 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for addict==2.4.0
# Best match: addict 2.4.0
# Adding addict 2.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for filelock==3.18.0
# Best match: filelock 3.18.0
# Adding filelock 3.18.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for beautifulsoup4==4.13.4
# Best match: beautifulsoup4 4.13.4
# Adding beautifulsoup4 4.13.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for platformdirs==4.3.8
# Best match: platformdirs 4.3.8
# Adding platformdirs 4.3.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for sympy==1.13.1
# Best match: sympy 1.13.1
# Adding sympy 1.13.1 to easy-install.pth file
# Installing isympy script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for triton==3.2.0
# Best match: triton 3.2.0
# Adding triton 3.2.0 to easy-install.pth file
# Installing proton script to /usr/local/bin
# Installing proton-viewer script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-nvjitlink-cu12==12.4.127
# Best match: nvidia-nvjitlink-cu12 12.4.127
# Adding nvidia-nvjitlink-cu12 12.4.127 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-nvtx-cu12==12.4.127
# Best match: nvidia-nvtx-cu12 12.4.127
# Adding nvidia-nvtx-cu12 12.4.127 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-nccl-cu12==2.21.5
# Best match: nvidia-nccl-cu12 2.21.5
# Adding nvidia-nccl-cu12 2.21.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cusparselt-cu12==0.6.2
# Best match: nvidia-cusparselt-cu12 0.6.2
# Adding nvidia-cusparselt-cu12 0.6.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cusparse-cu12==12.3.1.170
# Best match: nvidia-cusparse-cu12 12.3.1.170
# Adding nvidia-cusparse-cu12 12.3.1.170 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cusolver-cu12==11.6.1.9
# Best match: nvidia-cusolver-cu12 11.6.1.9
# Adding nvidia-cusolver-cu12 11.6.1.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-curand-cu12==10.3.5.147
# Best match: nvidia-curand-cu12 10.3.5.147
# Adding nvidia-curand-cu12 10.3.5.147 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cufft-cu12==11.2.1.3
# Best match: nvidia-cufft-cu12 11.2.1.3
# Adding nvidia-cufft-cu12 11.2.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cublas-cu12==12.4.5.8
# Best match: nvidia-cublas-cu12 12.4.5.8
# Adding nvidia-cublas-cu12 12.4.5.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cudnn-cu12==9.1.0.70
# Best match: nvidia-cudnn-cu12 9.1.0.70
# Adding nvidia-cudnn-cu12 9.1.0.70 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cuda-cupti-cu12==12.4.127
# Best match: nvidia-cuda-cupti-cu12 12.4.127
# Adding nvidia-cuda-cupti-cu12 12.4.127 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cuda-runtime-cu12==12.4.127
# Best match: nvidia-cuda-runtime-cu12 12.4.127
# Adding nvidia-cuda-runtime-cu12 12.4.127 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for nvidia-cuda-nvrtc-cu12==12.4.127
# Best match: nvidia-cuda-nvrtc-cu12 12.4.127
# Adding nvidia-cuda-nvrtc-cu12 12.4.127 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for fsspec==2025.3.0
# Best match: fsspec 2025.3.0
# Adding fsspec 2025.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for jinja2==3.1.6
# Best match: jinja2 3.1.6
# Adding jinja2 3.1.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for networkx==3.5
# Best match: networkx 3.5
# Adding networkx 3.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for typing-extensions==4.14.1
# Best match: typing-extensions 4.14.1
# Adding typing-extensions 4.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for werkzeug==3.1.3
# Best match: werkzeug 3.1.3
# Adding werkzeug 3.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for tensorboard-data-server==0.7.2
# Best match: tensorboard-data-server 0.7.2
# Adding tensorboard-data-server 0.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for setuptools==75.2.0
# Best match: setuptools 75.2.0
# Adding setuptools 75.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for protobuf==5.29.5
# Best match: protobuf 5.29.5
# Adding protobuf 5.29.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for packaging==25.0
# Best match: packaging 25.0
# Adding packaging 25.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for markdown==3.8.2
# Best match: markdown 3.8.2
# Adding markdown 3.8.2 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for grpcio==1.74.0
# Best match: grpcio 1.74.0
# Adding grpcio 1.74.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for lazy-loader==0.4
# Best match: lazy-loader 0.4
# Adding lazy-loader 0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for tifffile==2025.6.11
# Best match: tifffile 2025.6.11
# Adding tifffile 2025.6.11 to easy-install.pth file
# Installing lsm2bin script to /usr/local/bin
# Installing tiff2fsspec script to /usr/local/bin
# Installing tiffcomment script to /usr/local/bin
# Installing tifffile script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for imageio==2.37.0
# Best match: imageio 2.37.0
# Adding imageio 2.37.0 to easy-install.pth file
# Installing imageio_download_bin script to /usr/local/bin
# Installing imageio_remove_bin script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for certifi==2025.8.3
# Best match: certifi 2025.8.3
# Adding certifi 2025.8.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for urllib3==2.5.0
# Best match: urllib3 2.5.0
# Adding urllib3 2.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for idna==3.10
# Best match: idna 3.10
# Adding idna 3.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for charset-normalizer==3.4.2
# Best match: charset-normalizer 3.4.2
# Adding charset-normalizer 3.4.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for PySocks==1.7.1
# Best match: PySocks 1.7.1
# Adding PySocks 1.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for soupsieve==2.7
# Best match: soupsieve 2.7
# Adding soupsieve 2.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for MarkupSafe==3.0.2
# Best match: MarkupSafe 3.0.2
# Adding MarkupSafe 3.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Finished processing dependencies for basicsr==1.3.2
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/detection_Resnet50_Final.pth" to /content/CodeFormer/weights/facelib/detection_Resnet50_Final.pth
#
# 100% 104M/104M [00:00<00:00, 123MB/s]
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/parsing_parsenet.pth" to /content/CodeFormer/weights/facelib/parsing_parsenet.pth
#
# 100% 81.4M/81.4M [00:00<00:00, 382MB/s]
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/codeformer.pth" to /content/CodeFormer/weights/CodeFormer/codeformer.pth
#
# 100% 359M/359M [00:00<00:00, 417MB/s]
# /content

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from torch import optim

import albumentations as A
from albumentations.pytorch import ToTensorV2

import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics.pairwise import cosine_similarity

import os
import re
import zipfile
from pathlib import Path
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from timeit import default_timer as timer
import copy
import time
from scipy import stats

from facenet_pytorch import InceptionResnetV1, MTCNN

# %%
print(f"Versão do PyTorch: {torch.__version__}")
# Out:
# Versão do PyTorch: 2.6.0+cu124

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# Variáveis globais
SEED = 42
EPOCHS = 30
BATCH_SIZE = 32
IMG_SIZE = 160
LEARNING_RATE = 0.00005

# %% [markdown]
# # 1. Pegar os dados do SCface

# %% [markdown]
# ## 1.1 Descompactando o dataset e definindo os caminhos para as pastas do dataset

# %%
# Caminho zip do drive
zip_path = '/content/drive/MyDrive/PIBIC 2024-2025/SCface.zip'

# Caminho para qual iremos extrair
extract_path = Path("/content/scface_data")

# Extrai se o diretório de destino não existir
if not extract_path.exists():
  print(f"Criando diretório e descompactando em: {extract_path}")

  os.makedirs(extract_path, exist_ok=True)

  with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

  print("Dataset extraído com sucesso.")
else:
  print(f"Diretório '{extract_path}' já existe. Extração pulada.")
# Out:
# Criando diretório e descompactando em: /content/scface_data
# Dataset extraído com sucesso.

# %%
# Definindo os caminhos para o dataset
SCface_path = extract_path / "SCface_database"

SCFACE_MUGSHOT_FRONTAL_PATH = SCface_path / "mugshot_frontal_cropped_all"
SCFACE_MUGSHOT_ROTATION_PATH= SCface_path / "mugshot_rotation_all"
SCFACE_PROBE_PATH = SCface_path / "surveillance_cameras_all"

# Caminho para a pasta onde as novas imagens restauradas serão salvas
SCFACE_RESTORED_PROBE_PATH = SCface_path / "surveillance_cameras_all_restored"

# %%
print("Carregando e combinando imagens da galeria frontal e de rotação...")

frontal_files = list(Path(SCFACE_MUGSHOT_FRONTAL_PATH).glob('*.jpg'))

rotation_files = list(Path(SCFACE_MUGSHOT_ROTATION_PATH).glob('*.jpg'))

# Lista combinada de todas as imagens frontais e todas as imagens de rotação
all_gallery_filepaths = frontal_files + rotation_files

print(f"Total de {len(all_gallery_filepaths)} imagens de alta qualidade encontradas para treino/validação.")
# Out:
# Carregando e combinando imagens da galeria frontal e de rotação...
# Total de 1170 imagens de alta qualidade encontradas para treino/validação.

# %% [markdown]
# # 2. Data augmentation das imagens

# %%
# Transforms de treino
train_transform = A.Compose([
    # O resize será aplicado após pré-processamento do MTCNN
    A.Resize(height=IMG_SIZE, width=IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1, p=0.8),
    A.GaussNoise(p=0.2),
    A.OneOf([
        A.MotionBlur(p=0.3),
        A.MedianBlur(blur_limit=3, p=0.2),
        A.GaussianBlur(p=0.3),
    ], p=0.5),
    A.GridDistortion(p=0.2),
    A.CoarseDropout(
        num_holes_range=(1, 8),
        hole_height_range=(8, 16),
        hole_width_range=(8, 16),
        fill=0,
        p=0.5
    ),
    A.Rotate(limit=10, p=0.5),
    # Normaliza os pixels da imagem para o intervalo [-1, 1]
    A.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    ToTensorV2(),
])

# Transforms da avaliação
val_test_transform = A.Compose([
    A.Resize(height=IMG_SIZE, width=IMG_SIZE),
    A.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    ToTensorV2(),
])

# %% [markdown]
# # 3. Criando a classe Dataset e os DataLoaders para o SCface
#
# Aqui, a gallery (galeria) representa as imagens que representam as fotos de rostos, "estilo mugshot" e o probe representa as imagens de câmeras de segurança.

# %% [markdown]
# ## 3.1 Declaração da MTCNN e Restauração das imagens com CodeFormer

# %%
# Iniciando MTCNN
mtcnn = MTCNN(image_size=IMG_SIZE,
              margin=0,
              keep_all=False,
              device=device)

# %%
# Criando diretorio para imagens restauradas, caso nao exista
if not os.path.exists(SCFACE_RESTORED_PROBE_PATH):
  os.makedirs(SCFACE_RESTORED_PROBE_PATH, exist_ok=True)

# %%
# Comando para rodar a inferência do CodeFormer
# -w: peso da fidelidade à imagem original
# --bg_upsampler: para melhorar o fundo, totalmente opcional
# --face_upsample: garante que a face seja redimensionada
# !python CodeFormer/inference_codeformer.py -w 0.7 --input_path "{SCFACE_PROBE_PATH}" --output_path "{SCFACE_RESTORED_PROBE_PATH}" --bg_upsampler realesrgan --face_upsample
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 	detect 1 faces
# 	Input is a 16-bit image
# [809/2860] Processing: 037_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [810/2860] Processing: 037_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [811/2860] Processing: 037_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [812/2860] Processing: 037_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [813/2860] Processing: 037_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [814/2860] Processing: 037_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [815/2860] Processing: 038_cam1_1.jpg
# 	detect 1 faces
# [816/2860] Processing: 038_cam1_2.jpg
# 	detect 1 faces
# [817/2860] Processing: 038_cam1_3.jpg
# 	detect 1 faces
# [818/2860] Processing: 038_cam2_1.jpg
# 	detect 1 faces
# [819/2860] Processing: 038_cam2_2.jpg
# 	detect 1 faces
# [820/2860] Processing: 038_cam2_3.jpg
# 	detect 1 faces
# [821/2860] Processing: 038_cam3_1.jpg
# 	detect 1 faces
# [822/2860] Processing: 038_cam3_2.jpg
# 	detect 1 faces
# [823/2860] Processing: 038_cam3_3.jpg
# 	detect 1 faces
# [824/2860] Processing: 038_cam4_1.jpg
# 	detect 1 faces
# [825/2860] Processing: 038_cam4_2.jpg
# 	detect 1 faces
# [826/2860] Processing: 038_cam4_3.jpg
# 	detect 1 faces
# [827/2860] Processing: 038_cam5_1.jpg
# 	detect 1 faces
# [828/2860] Processing: 038_cam5_2.jpg
# 	detect 1 faces
# [829/2860] Processing: 038_cam5_3.jpg
# 	detect 1 faces
# [830/2860] Processing: 038_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [831/2860] Processing: 038_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [832/2860] Processing: 038_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [833/2860] Processing: 038_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [834/2860] Processing: 038_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [835/2860] Processing: 038_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [836/2860] Processing: 038_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [837/2860] Processing: 039_cam1_1.jpg
# 	detect 1 faces
# [838/2860] Processing: 039_cam1_2.jpg
# 	detect 1 faces
# [839/2860] Processing: 039_cam1_3.jpg
# 	detect 1 faces
# [840/2860] Processing: 039_cam2_1.jpg
# 	detect 1 faces
# [841/2860] Processing: 039_cam2_2.jpg
# 	detect 1 faces
# [842/2860] Processing: 039_cam2_3.jpg
# 	detect 1 faces
# [843/2860] Processing: 039_cam3_1.jpg
# 	detect 1 faces
# [844/2860] Processing: 039_cam3_2.jpg
# 	detect 1 faces
# [845/2860] Processing: 039_cam3_3.jpg
# 	detect 1 faces
# [846/2860] Processing: 039_cam4_1.jpg
# 	detect 1 faces
# [847/2860] Processing: 039_cam4_2.jpg
# 	detect 1 faces
# [848/2860] Processing: 039_cam4_3.jpg
# 	detect 1 faces
# [849/2860] Processing: 039_cam5_1.jpg
# 	detect 1 faces
# [850/2860] Processing: 039_cam5_2.jpg
# 	detect 1 faces
# [851/2860] Processing: 039_cam5_3.jpg
# 	detect 1 faces
# [852/2860] Processing: 039_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [853/2860] Processing: 039_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [854/2860] Processing: 039_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [855/2860] Processing: 039_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [856/2860] Processing: 039_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [857/2860] Processing: 039_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [858/2860] Processing: 039_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [859/2860] Processing: 040_cam1_1.jpg
# 	detect 1 faces
# [860/2860] Processing: 040_cam1_2.jpg
# 	detect 1 faces
# [861/2860] Processing: 040_cam1_3.jpg
# 	detect 1 faces
# [862/2860] Processing: 040_cam2_1.jpg
# 	detect 1 faces
# [863/2860] Processing: 040_cam2_2.jpg
# 	detect 1 faces
# [864/2860] Processing: 040_cam2_3.jpg
# 	detect 1 faces
# [865/2860] Processing: 040_cam3_1.jpg
# 	detect 1 faces
# [866/2860] Processing: 040_cam3_2.jpg
# 	detect 1 faces
# [867/2860] Processing: 040_cam3_3.jpg
# 	detect 1 faces
# [868/2860] Processing: 040_cam4_1.jpg
# 	detect 1 faces
# [869/2860] Processing: 040_cam4_2.jpg
# 	detect 1 faces
# [870/2860] Processing: 040_cam4_3.jpg
# 	detect 1 faces
# [871/2860] Processing: 040_cam5_1.jpg
# 	detect 1 faces
# [872/2860] Processing: 040_cam5_2.jpg
# 	detect 1 faces
# [873/2860] Processing: 040_cam5_3.jpg
# 	detect 1 faces
# [874/2860] Processing: 040_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [875/2860] Processing: 040_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [876/2860] Processing: 040_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [877/2860] Processing: 040_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [878/2860] Processing: 040_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [879/2860] Processing: 040_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [880/2860] Processing: 040_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [881/2860] Processing: 041_cam1_1.jpg
# 	detect 1 faces
# [882/2860] Processing: 041_cam1_2.jpg
# 	detect 1 faces
# [883/2860] Processing: 041_cam1_3.jpg
# 	detect 1 faces
# [884/2860] Processing: 041_cam2_1.jpg
# 	detect 1 faces
# [885/2860] Processing: 041_cam2_2.jpg
# 	detect 1 faces
# [886/2860] Processing: 041_cam2_3.jpg
# 	detect 1 faces
# [887/2860] Processing: 041_cam3_1.jpg
# 	detect 1 faces
# [888/2860] Processing: 041_cam3_2.jpg
# 	detect 1 faces
# [889/2860] Processing: 041_cam3_3.jpg
# 	detect 1 faces
# [890/2860] Processing: 041_cam4_1.jpg
# 	detect 1 faces
# [891/2860] Processing: 041_cam4_2.jpg
# 	detect 1 faces
# [892/2860] Processing: 041_cam4_3.jpg
# 	detect 1 faces
# [893/2860] Processing: 041_cam5_1.jpg
# 	detect 1 faces
# [894/2860] Processing: 041_cam5_2.jpg
# 	detect 1 faces
# [895/2860] Processing: 041_cam5_3.jpg
# 	detect 1 faces
# [896/2860] Processing: 041_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [897/2860] Processing: 041_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [898/2860] Processing: 041_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [899/2860] Processing: 041_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [900/2860] Processing: 041_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [901/2860] Processing: 041_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [902/2860] Processing: 041_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [903/2860] Processing: 042_cam1_1.jpg
# 	detect 1 faces
# [904/2860] Processing: 042_cam1_2.jpg
# 	detect 1 faces
# [905/2860] Processing: 042_cam1_3.jpg
# 	detect 1 faces
# [906/2860] Processing: 042_cam2_1.jpg
# 	detect 1 faces
# [907/2860] Processing: 042_cam2_2.jpg
# 	detect 1 faces
# [908/2860] Processing: 042_cam2_3.jpg
# 	detect 1 faces
# [909/2860] Processing: 042_cam3_1.jpg
# 	detect 1 faces
# [910/2860] Processing: 042_cam3_2.jpg
# 	detect 1 faces
# [911/2860] Processing: 042_cam3_3.jpg
# 	detect 1 faces
# [912/2860] Processing: 042_cam4_1.jpg
# 	detect 1 faces
# [913/2860] Processing: 042_cam4_2.jpg
# 	detect 1 faces
# [914/2860] Processing: 042_cam4_3.jpg
# 	detect 1 faces
# [915/2860] Processing: 042_cam5_1.jpg
# 	detect 1 faces
# [916/2860] Processing: 042_cam5_2.jpg
# 	detect 1 faces
# [917/2860] Processing: 042_cam5_3.jpg
# 	detect 1 faces
# [918/2860] Processing: 042_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [919/2860] Processing: 042_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [920/2860] Processing: 042_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [921/2860] Processing: 042_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [922/2860] Processing: 042_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [923/2860] Processing: 042_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [924/2860] Processing: 042_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [925/2860] Processing: 043_cam1_1.jpg
# 	detect 1 faces
# [926/2860] Processing: 043_cam1_2.jpg
# 	detect 1 faces
# [927/2860] Processing: 043_cam1_3.jpg
# 	detect 1 faces
# [928/2860] Processing: 043_cam2_1.jpg
# 	detect 1 faces
# [929/2860] Processing: 043_cam2_2.jpg
# 	detect 1 faces
# [930/2860] Processing: 043_cam2_3.jpg
# 	detect 1 faces
# [931/2860] Processing: 043_cam3_1.jpg
# 	detect 1 faces
# [932/2860] Processing: 043_cam3_2.jpg
# 	detect 1 faces
# [933/2860] Processing: 043_cam3_3.jpg
# 	detect 1 faces
# [934/2860] Processing: 043_cam4_1.jpg
# 	detect 1 faces
# [935/2860] Processing: 043_cam4_2.jpg
# 	detect 1 faces
# [936/2860] Processing: 043_cam4_3.jpg
# 	detect 1 faces
# [937/2860] Processing: 043_cam5_1.jpg
# 	detect 1 faces
# [938/2860] Processing: 043_cam5_2.jpg
# 	detect 1 faces
# [939/2860] Processing: 043_cam5_3.jpg
# 	detect 1 faces
# [940/2860] Processing: 043_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [941/2860] Processing: 043_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [942/2860] Processing: 043_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [943/2860] Processing: 043_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [944/2860] Processing: 043_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [945/2860] Processing: 043_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [946/2860] Processing: 043_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [947/2860] Processing: 044_cam1_1.jpg
# 	detect 1 faces
# [948/2860] Processing: 044_cam1_2.jpg
# 	detect 1 faces
# [949/2860] Processing: 044_cam1_3.jpg
# 	detect 1 faces
# [950/2860] Processing: 044_cam2_1.jpg
# 	detect 1 faces
# [951/2860] Processing: 044_cam2_2.jpg
# 	detect 1 faces
# [952/2860] Processing: 044_cam2_3.jpg
# 	detect 1 faces
# [953/2860] Processing: 044_cam3_1.jpg
# 	detect 1 faces
# [954/2860] Processing: 044_cam3_2.jpg
# 	detect 1 faces
# [955/2860] Processing: 044_cam3_3.jpg
# 	detect 1 faces
# [956/2860] Processing: 044_cam4_1.jpg
# 	detect 1 faces
# [957/2860] Processing: 044_cam4_2.jpg
# 	detect 1 faces
# [958/2860] Processing: 044_cam4_3.jpg
# 	detect 1 faces
# [959/2860] Processing: 044_cam5_1.jpg
# 	detect 1 faces
# [960/2860] Processing: 044_cam5_2.jpg
# 	detect 1 faces
# [961/2860] Processing: 044_cam5_3.jpg
# 	detect 1 faces
# [962/2860] Processing: 044_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [963/2860] Processing: 044_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [964/2860] Processing: 044_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [965/2860] Processing: 044_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [966/2860] Processing: 044_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [967/2860] Processing: 044_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [968/2860] Processing: 044_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [969/2860] Processing: 045_cam1_1.jpg
# 	detect 1 faces
# [970/2860] Processing: 045_cam1_2.jpg
# 	detect 1 faces
# [971/2860] Processing: 045_cam1_3.jpg
# 	detect 1 faces
# [972/2860] Processing: 045_cam2_1.jpg
# 	detect 1 faces
# [973/2860] Processing: 045_cam2_2.jpg
# 	detect 1 faces
# [974/2860] Processing: 045_cam2_3.jpg
# 	detect 1 faces
# [975/2860] Processing: 045_cam3_1.jpg
# 	detect 1 faces
# [976/2860] Processing: 045_cam3_2.jpg
# 	detect 1 faces
# [977/2860] Processing: 045_cam3_3.jpg
# 	detect 1 faces
# [978/2860] Processing: 045_cam4_1.jpg
# 	detect 1 faces
# [979/2860] Processing: 045_cam4_2.jpg
# 	detect 1 faces
# [980/2860] Processing: 045_cam4_3.jpg
# 	detect 1 faces
# [981/2860] Processing: 045_cam5_1.jpg
# 	detect 1 faces
# [982/2860] Processing: 045_cam5_2.jpg
# 	detect 1 faces
# [983/2860] Processing: 045_cam5_3.jpg
# 	detect 1 faces
# [984/2860] Processing: 045_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [985/2860] Processing: 045_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [986/2860] Processing: 045_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [987/2860] Processing: 045_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [988/2860] Processing: 045_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [989/2860] Processing: 045_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [990/2860] Processing: 045_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [991/2860] Processing: 046_cam1_1.jpg
# 	detect 1 faces
# [992/2860] Processing: 046_cam1_2.jpg
# 	detect 1 faces
# [993/2860] Processing: 046_cam1_3.jpg
# 	detect 1 faces
# [994/2860] Processing: 046_cam2_1.jpg
# 	detect 1 faces
# [995/2860] Processing: 046_cam2_2.jpg
# 	detect 2 faces
# [996/2860] Processing: 046_cam2_3.jpg
# 	detect 1 faces
# [997/2860] Processing: 046_cam3_1.jpg
# 	detect 1 faces
# [998/2860] Processing: 046_cam3_2.jpg
# 	detect 1 faces
# [999/2860] Processing: 046_cam3_3.jpg
# 	detect 1 faces
# [1000/2860] Processing: 046_cam4_1.jpg
# 	detect 1 faces
# [1001/2860] Processing: 046_cam4_2.jpg
# 	detect 1 faces
# [1002/2860] Processing: 046_cam4_3.jpg
# 	detect 1 faces
# [1003/2860] Processing: 046_cam5_1.jpg
# 	detect 1 faces
# [1004/2860] Processing: 046_cam5_2.jpg
# 	detect 1 faces
# [1005/2860] Processing: 046_cam5_3.jpg
# 	detect 1 faces
# [1006/2860] Processing: 046_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1007/2860] Processing: 046_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1008/2860] Processing: 046_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1009/2860] Processing: 046_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1010/2860] Processing: 046_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1011/2860] Processing: 046_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1012/2860] Processing: 046_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1013/2860] Processing: 047_cam1_1.jpg
# 	detect 1 faces
# [1014/2860] Processing: 047_cam1_2.jpg
# 	detect 1 faces
# [1015/2860] Processing: 047_cam1_3.jpg
# 	detect 1 faces
# [1016/2860] Processing: 047_cam2_1.jpg
# 	detect 1 faces
# [1017/2860] Processing: 047_cam2_2.jpg
# 	detect 1 faces
# [1018/2860] Processing: 047_cam2_3.jpg
# 	detect 1 faces
# [1019/2860] Processing: 047_cam3_1.jpg
# 	detect 1 faces
# [1020/2860] Processing: 047_cam3_2.jpg
# 	detect 1 faces
# [1021/2860] Processing: 047_cam3_3.jpg
# 	detect 1 faces
# [1022/2860] Processing: 047_cam4_1.jpg
# 	detect 1 faces
# [1023/2860] Processing: 047_cam4_2.jpg
# 	detect 1 faces
# [1024/2860] Processing: 047_cam4_3.jpg
# 	detect 1 faces
# [1025/2860] Processing: 047_cam5_1.jpg
# 	detect 1 faces
# [1026/2860] Processing: 047_cam5_2.jpg
# 	detect 1 faces
# [1027/2860] Processing: 047_cam5_3.jpg
# 	detect 1 faces
# [1028/2860] Processing: 047_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1029/2860] Processing: 047_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1030/2860] Processing: 047_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1031/2860] Processing: 047_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1032/2860] Processing: 047_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1033/2860] Processing: 047_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1034/2860] Processing: 047_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1035/2860] Processing: 048_cam1_1.jpg
# 	detect 1 faces
# [1036/2860] Processing: 048_cam1_2.jpg
# 	detect 1 faces
# [1037/2860] Processing: 048_cam1_3.jpg
# 	detect 1 faces
# [1038/2860] Processing: 048_cam2_1.jpg
# 	detect 1 faces
# [1039/2860] Processing: 048_cam2_2.jpg
# 	detect 1 faces
# [1040/2860] Processing: 048_cam2_3.jpg
# 	detect 1 faces
# [1041/2860] Processing: 048_cam3_1.jpg
# 	detect 1 faces
# [1042/2860] Processing: 048_cam3_2.jpg
# 	detect 1 faces
# [1043/2860] Processing: 048_cam3_3.jpg
# 	detect 1 faces
# [1044/2860] Processing: 048_cam4_1.jpg
# 	detect 1 faces
# [1045/2860] Processing: 048_cam4_2.jpg
# 	detect 1 faces
# [1046/2860] Processing: 048_cam4_3.jpg
# 	detect 1 faces
# [1047/2860] Processing: 048_cam5_1.jpg
# 	detect 1 faces
# [1048/2860] Processing: 048_cam5_2.jpg
# 	detect 1 faces
# [1049/2860] Processing: 048_cam5_3.jpg
# 	detect 1 faces
# [1050/2860] Processing: 048_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1051/2860] Processing: 048_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1052/2860] Processing: 048_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1053/2860] Processing: 048_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1054/2860] Processing: 048_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1055/2860] Processing: 048_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1056/2860] Processing: 048_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1057/2860] Processing: 049_cam1_1.jpg
# 	detect 1 faces
# [1058/2860] Processing: 049_cam1_2.jpg
# 	detect 1 faces
# [1059/2860] Processing: 049_cam1_3.jpg
# 	detect 1 faces
# [1060/2860] Processing: 049_cam2_1.jpg
# 	detect 1 faces
# [1061/2860] Processing: 049_cam2_2.jpg
# 	detect 1 faces
# [1062/2860] Processing: 049_cam2_3.jpg
# 	detect 1 faces
# [1063/2860] Processing: 049_cam3_1.jpg
# 	detect 1 faces
# [1064/2860] Processing: 049_cam3_2.jpg
# 	detect 1 faces
# [1065/2860] Processing: 049_cam3_3.jpg
# 	detect 1 faces
# [1066/2860] Processing: 049_cam4_1.jpg
# 	detect 1 faces
# [1067/2860] Processing: 049_cam4_2.jpg
# 	detect 1 faces
# [1068/2860] Processing: 049_cam4_3.jpg
# 	detect 1 faces
# [1069/2860] Processing: 049_cam5_1.jpg
# 	detect 1 faces
# [1070/2860] Processing: 049_cam5_2.jpg
# 	detect 1 faces
# [1071/2860] Processing: 049_cam5_3.jpg
# 	detect 1 faces
# [1072/2860] Processing: 049_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1073/2860] Processing: 049_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1074/2860] Processing: 049_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1075/2860] Processing: 049_cam7_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1076/2860] Processing: 049_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1077/2860] Processing: 049_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1078/2860] Processing: 049_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1079/2860] Processing: 050_cam1_1.jpg
# 	detect 2 faces
# [1080/2860] Processing: 050_cam1_2.jpg
# 	detect 1 faces
# [1081/2860] Processing: 050_cam1_3.jpg
# 	detect 1 faces
# [1082/2860] Processing: 050_cam2_1.jpg
# 	detect 1 faces
# [1083/2860] Processing: 050_cam2_2.jpg
# 	detect 1 faces
# [1084/2860] Processing: 050_cam2_3.jpg
# 	detect 1 faces
# [1085/2860] Processing: 050_cam3_1.jpg
# 	detect 1 faces
# [1086/2860] Processing: 050_cam3_2.jpg
# 	detect 1 faces
# [1087/2860] Processing: 050_cam3_3.jpg
# 	detect 1 faces
# [1088/2860] Processing: 050_cam4_1.jpg
# 	detect 1 faces
# [1089/2860] Processing: 050_cam4_2.jpg
# 	detect 1 faces
# [1090/2860] Processing: 050_cam4_3.jpg
# 	detect 1 faces
# [1091/2860] Processing: 050_cam5_1.jpg
# 	detect 1 faces
# [1092/2860] Processing: 050_cam5_2.jpg
# 	detect 1 faces
# [1093/2860] Processing: 050_cam5_3.jpg
# 	detect 1 faces
# [1094/2860] Processing: 050_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1095/2860] Processing: 050_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1096/2860] Processing: 050_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1097/2860] Processing: 050_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1098/2860] Processing: 050_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1099/2860] Processing: 050_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1100/2860] Processing: 050_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1101/2860] Processing: 051_cam1_1.jpg
# 	detect 1 faces
# [1102/2860] Processing: 051_cam1_2.jpg
# 	detect 1 faces
# [1103/2860] Processing: 051_cam1_3.jpg
# 	detect 1 faces
# [1104/2860] Processing: 051_cam2_1.jpg
# 	detect 1 faces
# [1105/2860] Processing: 051_cam2_2.jpg
# 	detect 1 faces
# [1106/2860] Processing: 051_cam2_3.jpg
# 	detect 1 faces
# [1107/2860] Processing: 051_cam3_1.jpg
# 	detect 1 faces
# [1108/2860] Processing: 051_cam3_2.jpg
# 	detect 1 faces
# [1109/2860] Processing: 051_cam3_3.jpg
# 	detect 1 faces
# [1110/2860] Processing: 051_cam4_1.jpg
# 	detect 1 faces
# [1111/2860] Processing: 051_cam4_2.jpg
# 	detect 1 faces
# [1112/2860] Processing: 051_cam4_3.jpg
# 	detect 1 faces
# [1113/2860] Processing: 051_cam5_1.jpg
# 	detect 1 faces
# [1114/2860] Processing: 051_cam5_2.jpg
# 	detect 1 faces
# [1115/2860] Processing: 051_cam5_3.jpg
# 	detect 1 faces
# [1116/2860] Processing: 051_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1117/2860] Processing: 051_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1118/2860] Processing: 051_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1119/2860] Processing: 051_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1120/2860] Processing: 051_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1121/2860] Processing: 051_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1122/2860] Processing: 051_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1123/2860] Processing: 052_cam1_1.jpg
# 	detect 1 faces
# [1124/2860] Processing: 052_cam1_2.jpg
# 	detect 1 faces
# [1125/2860] Processing: 052_cam1_3.jpg
# 	detect 1 faces
# [1126/2860] Processing: 052_cam2_1.jpg
# 	detect 1 faces
# [1127/2860] Processing: 052_cam2_2.jpg
# 	detect 1 faces
# [1128/2860] Processing: 052_cam2_3.jpg
# 	detect 1 faces
# [1129/2860] Processing: 052_cam3_1.jpg
# 	detect 1 faces
# [1130/2860] Processing: 052_cam3_2.jpg
# 	detect 1 faces
# [1131/2860] Processing: 052_cam3_3.jpg
# 	detect 1 faces
# [1132/2860] Processing: 052_cam4_1.jpg
# 	detect 1 faces
# [1133/2860] Processing: 052_cam4_2.jpg
# 	detect 1 faces
# [1134/2860] Processing: 052_cam4_3.jpg
# 	detect 1 faces
# [1135/2860] Processing: 052_cam5_1.jpg
# 	detect 1 faces
# [1136/2860] Processing: 052_cam5_2.jpg
# 	detect 1 faces
# [1137/2860] Processing: 052_cam5_3.jpg
# 	detect 1 faces
# [1138/2860] Processing: 052_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1139/2860] Processing: 052_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1140/2860] Processing: 052_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1141/2860] Processing: 052_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1142/2860] Processing: 052_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1143/2860] Processing: 052_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1144/2860] Processing: 052_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# [1145/2860] Processing: 053_cam1_1.jpg
# 	detect 1 faces
# [1146/2860] Processing: 053_cam1_2.jpg
# 	detect 1 faces
# [1147/2860] Processing: 053_cam1_3.jpg
# 	detect 1 faces
# [1148/2860] Processing: 053_cam2_1.jpg
# 	detect 1 faces
# [1149/2860] Processing: 053_cam2_2.jpg
# 	detect 1 faces
# [1150/2860] Processing: 053_cam2_3.jpg
# 	detect 1 faces
# [1151/2860] Processing: 053_cam3_1.jpg
# 	detect 1 faces
# [1152/2860] Processing: 053_cam3_2.jpg
# 	detect 1 faces
# [1153/2860] Processing: 053_cam3_3.jpg
# 	detect 1 faces
# [1154/2860] Processing: 053_cam4_1.jpg
# 	detect 1 faces
# [1155/2860] Processing: 053_cam4_2.jpg
# 	detect 1 faces
# [1156/2860] Processing: 053_cam4_3.jpg
# 	detect 1 faces
# [1157/2860] Processing: 053_cam5_1.jpg
# 	detect 0 faces
# [1158/2860] Processing: 053_cam5_2.jpg
# 	detect 1 faces
# [1159/2860] Processing: 053_cam5_3.jpg
# 	detect 1 faces
# [1160/2860] Processing: 053_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1161/2860] Processing: 053_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1162/2860] Processing: 053_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1163/2860] Processing: 053_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1164/2860] Processing: 053_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1165/2860] Processing: 053_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1166/2860] Processing: 053_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1167/2860] Processing: 054_cam1_1.jpg
# 	detect 1 faces
# [1168/2860] Processing: 054_cam1_2.jpg
# 	detect 1 faces
# [1169/2860] Processing: 054_cam1_3.jpg
# 	detect 1 faces
# [1170/2860] Processing: 054_cam2_1.jpg
# 	detect 1 faces
# [1171/2860] Processing: 054_cam2_2.jpg
# 	detect 1 faces
# [1172/2860] Processing: 054_cam2_3.jpg
# 	detect 1 faces
# [1173/2860] Processing: 054_cam3_1.jpg
# 	detect 2 faces
# [1174/2860] Processing: 054_cam3_2.jpg
# 	detect 1 faces
# [1175/2860] Processing: 054_cam3_3.jpg
# 	detect 1 faces
# [1176/2860] Processing: 054_cam4_1.jpg
# 	detect 1 faces
# [1177/2860] Processing: 054_cam4_2.jpg
# 	detect 1 faces
# [1178/2860] Processing: 054_cam4_3.jpg
# 	detect 1 faces
# [1179/2860] Processing: 054_cam5_1.jpg
# 	detect 1 faces
# [1180/2860] Processing: 054_cam5_2.jpg
# 	detect 1 faces
# [1181/2860] Processing: 054_cam5_3.jpg
# 	detect 1 faces
# [1182/2860] Processing: 054_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1183/2860] Processing: 054_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1184/2860] Processing: 054_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1185/2860] Processing: 054_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1186/2860] Processing: 054_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1187/2860] Processing: 054_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1188/2860] Processing: 054_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1189/2860] Processing: 055_cam1_1.jpg
# 	detect 1 faces
# [1190/2860] Processing: 055_cam1_2.jpg
# 	detect 1 faces
# [1191/2860] Processing: 055_cam1_3.jpg
# 	detect 1 faces
# [1192/2860] Processing: 055_cam2_1.jpg
# 	detect 1 faces
# [1193/2860] Processing: 055_cam2_2.jpg
# 	detect 1 faces
# [1194/2860] Processing: 055_cam2_3.jpg
# 	detect 1 faces
# [1195/2860] Processing: 055_cam3_1.jpg
# 	detect 1 faces
# [1196/2860] Processing: 055_cam3_2.jpg
# 	detect 1 faces
# [1197/2860] Processing: 055_cam3_3.jpg
# 	detect 1 faces
# [1198/2860] Processing: 055_cam4_1.jpg
# 	detect 1 faces
# [1199/2860] Processing: 055_cam4_2.jpg
# 	detect 1 faces
# [1200/2860] Processing: 055_cam4_3.jpg
# 	detect 1 faces
# [1201/2860] Processing: 055_cam5_1.jpg
# 	detect 1 faces
# [1202/2860] Processing: 055_cam5_2.jpg
# 	detect 1 faces
# [1203/2860] Processing: 055_cam5_3.jpg
# 	detect 1 faces
# [1204/2860] Processing: 055_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1205/2860] Processing: 055_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1206/2860] Processing: 055_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1207/2860] Processing: 055_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1208/2860] Processing: 055_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1209/2860] Processing: 055_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1210/2860] Processing: 055_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1211/2860] Processing: 056_cam1_1.jpg
# 	detect 1 faces
# [1212/2860] Processing: 056_cam1_2.jpg
# 	detect 1 faces
# [1213/2860] Processing: 056_cam1_3.jpg
# 	detect 1 faces
# [1214/2860] Processing: 056_cam2_1.jpg
# 	detect 1 faces
# [1215/2860] Processing: 056_cam2_2.jpg
# 	detect 1 faces
# [1216/2860] Processing: 056_cam2_3.jpg
# 	detect 1 faces
# [1217/2860] Processing: 056_cam3_1.jpg
# 	detect 1 faces
# [1218/2860] Processing: 056_cam3_2.jpg
# 	detect 1 faces
# [1219/2860] Processing: 056_cam3_3.jpg
# 	detect 1 faces
# [1220/2860] Processing: 056_cam4_1.jpg
# 	detect 1 faces
# [1221/2860] Processing: 056_cam4_2.jpg
# 	detect 1 faces
# [1222/2860] Processing: 056_cam4_3.jpg
# 	detect 1 faces
# [1223/2860] Processing: 056_cam5_1.jpg
# 	detect 1 faces
# [1224/2860] Processing: 056_cam5_2.jpg
# 	detect 1 faces
# [1225/2860] Processing: 056_cam5_3.jpg
# 	detect 1 faces
# [1226/2860] Processing: 056_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1227/2860] Processing: 056_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1228/2860] Processing: 056_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1229/2860] Processing: 056_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1230/2860] Processing: 056_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1231/2860] Processing: 056_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1232/2860] Processing: 056_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1233/2860] Processing: 057_cam1_1.jpg
# 	detect 1 faces
# [1234/2860] Processing: 057_cam1_2.jpg
# 	detect 1 faces
# [1235/2860] Processing: 057_cam1_3.jpg
# 	detect 1 faces
# [1236/2860] Processing: 057_cam2_1.jpg
# 	detect 1 faces
# [1237/2860] Processing: 057_cam2_2.jpg
# 	detect 1 faces
# [1238/2860] Processing: 057_cam2_3.jpg
# 	detect 1 faces
# [1239/2860] Processing: 057_cam3_1.jpg
# 	detect 1 faces
# [1240/2860] Processing: 057_cam3_2.jpg
# 	detect 1 faces
# [1241/2860] Processing: 057_cam3_3.jpg
# 	detect 1 faces
# [1242/2860] Processing: 057_cam4_1.jpg
# 	detect 1 faces
# [1243/2860] Processing: 057_cam4_2.jpg
# 	detect 1 faces
# [1244/2860] Processing: 057_cam4_3.jpg
# 	detect 1 faces
# [1245/2860] Processing: 057_cam5_1.jpg
# 	detect 1 faces
# [1246/2860] Processing: 057_cam5_2.jpg
# 	detect 1 faces
# [1247/2860] Processing: 057_cam5_3.jpg
# 	detect 1 faces
# [1248/2860] Processing: 057_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1249/2860] Processing: 057_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1250/2860] Processing: 057_cam6_3.jpg
# 	detect 1 faces
# [1251/2860] Processing: 057_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1252/2860] Processing: 057_cam7_2.jpg
# Grayscale input: True
# 	detect 0 faces
# [1253/2860] Processing: 057_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1254/2860] Processing: 057_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1255/2860] Processing: 058_cam1_1.jpg
# 	detect 1 faces
# [1256/2860] Processing: 058_cam1_2.jpg
# 	detect 1 faces
# [1257/2860] Processing: 058_cam1_3.jpg
# 	detect 1 faces
# [1258/2860] Processing: 058_cam2_1.jpg
# 	detect 1 faces
# [1259/2860] Processing: 058_cam2_2.jpg
# 	detect 1 faces
# [1260/2860] Processing: 058_cam2_3.jpg
# 	detect 1 faces
# [1261/2860] Processing: 058_cam3_1.jpg
# 	detect 1 faces
# [1262/2860] Processing: 058_cam3_2.jpg
# 	detect 1 faces
# [1263/2860] Processing: 058_cam3_3.jpg
# 	detect 1 faces
# [1264/2860] Processing: 058_cam4_1.jpg
# 	detect 1 faces
# [1265/2860] Processing: 058_cam4_2.jpg
# 	detect 1 faces
# [1266/2860] Processing: 058_cam4_3.jpg
# 	detect 1 faces
# [1267/2860] Processing: 058_cam5_1.jpg
# 	detect 1 faces
# [1268/2860] Processing: 058_cam5_2.jpg
# 	detect 1 faces
# [1269/2860] Processing: 058_cam5_3.jpg
# 	detect 1 faces
# [1270/2860] Processing: 058_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1271/2860] Processing: 058_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1272/2860] Processing: 058_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1273/2860] Processing: 058_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1274/2860] Processing: 058_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1275/2860] Processing: 058_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1276/2860] Processing: 058_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1277/2860] Processing: 059_cam1_1.jpg
# 	detect 1 faces
# [1278/2860] Processing: 059_cam1_2.jpg
# 	detect 1 faces
# [1279/2860] Processing: 059_cam1_3.jpg
# 	detect 1 faces
# [1280/2860] Processing: 059_cam2_1.jpg
# 	detect 1 faces
# [1281/2860] Processing: 059_cam2_2.jpg
# 	detect 1 faces
# [1282/2860] Processing: 059_cam2_3.jpg
# 	detect 1 faces
# [1283/2860] Processing: 059_cam3_1.jpg
# 	detect 1 faces
# [1284/2860] Processing: 059_cam3_2.jpg
# 	detect 1 faces
# [1285/2860] Processing: 059_cam3_3.jpg
# 	detect 1 faces
# [1286/2860] Processing: 059_cam4_1.jpg
# 	detect 1 faces
# [1287/2860] Processing: 059_cam4_2.jpg
# 	detect 1 faces
# [1288/2860] Processing: 059_cam4_3.jpg
# 	detect 1 faces
# [1289/2860] Processing: 059_cam5_1.jpg
# 	detect 1 faces
# [1290/2860] Processing: 059_cam5_2.jpg
# 	detect 1 faces
# [1291/2860] Processing: 059_cam5_3.jpg
# 	detect 1 faces
# [1292/2860] Processing: 059_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1293/2860] Processing: 059_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1294/2860] Processing: 059_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1295/2860] Processing: 059_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1296/2860] Processing: 059_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1297/2860] Processing: 059_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1298/2860] Processing: 059_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1299/2860] Processing: 060_cam1_1.jpg
# 	detect 1 faces
# [1300/2860] Processing: 060_cam1_2.jpg
# 	detect 1 faces
# [1301/2860] Processing: 060_cam1_3.jpg
# 	detect 1 faces
# [1302/2860] Processing: 060_cam2_1.jpg
# 	detect 1 faces
# [1303/2860] Processing: 060_cam2_2.jpg
# 	detect 1 faces
# [1304/2860] Processing: 060_cam2_3.jpg
# 	detect 1 faces
# [1305/2860] Processing: 060_cam3_1.jpg
# 	detect 1 faces
# [1306/2860] Processing: 060_cam3_2.jpg
# 	detect 1 faces
# [1307/2860] Processing: 060_cam3_3.jpg
# 	detect 1 faces
# [1308/2860] Processing: 060_cam4_1.jpg
# 	detect 1 faces
# [1309/2860] Processing: 060_cam4_2.jpg
# 	detect 1 faces
# [1310/2860] Processing: 060_cam4_3.jpg
# 	detect 1 faces
# [1311/2860] Processing: 060_cam5_1.jpg
# 	detect 1 faces
# [1312/2860] Processing: 060_cam5_2.jpg
# 	detect 1 faces
# [1313/2860] Processing: 060_cam5_3.jpg
# 	detect 1 faces
# [1314/2860] Processing: 060_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1315/2860] Processing: 060_cam6_2.jpg
# Grayscale input: True
# 	detect 0 faces
# [1316/2860] Processing: 060_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1317/2860] Processing: 060_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1318/2860] Processing: 060_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1319/2860] Processing: 060_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1320/2860] Processing: 060_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1321/2860] Processing: 061_cam1_1.jpg
# 	detect 1 faces
# [1322/2860] Processing: 061_cam1_2.jpg
# 	detect 1 faces
# [1323/2860] Processing: 061_cam1_3.jpg
# 	detect 1 faces
# [1324/2860] Processing: 061_cam2_1.jpg
# 	detect 1 faces
# [1325/2860] Processing: 061_cam2_2.jpg
# 	detect 1 faces
# [1326/2860] Processing: 061_cam2_3.jpg
# 	detect 1 faces
# [1327/2860] Processing: 061_cam3_1.jpg
# 	detect 1 faces
# [1328/2860] Processing: 061_cam3_2.jpg
# 	detect 1 faces
# [1329/2860] Processing: 061_cam3_3.jpg
# 	detect 1 faces
# [1330/2860] Processing: 061_cam4_1.jpg
# 	detect 1 faces
# [1331/2860] Processing: 061_cam4_2.jpg
# 	detect 1 faces
# [1332/2860] Processing: 061_cam4_3.jpg
# 	detect 1 faces
# [1333/2860] Processing: 061_cam5_1.jpg
# 	detect 1 faces
# [1334/2860] Processing: 061_cam5_2.jpg
# 	detect 1 faces
# [1335/2860] Processing: 061_cam5_3.jpg
# 	detect 1 faces
# [1336/2860] Processing: 061_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1337/2860] Processing: 061_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1338/2860] Processing: 061_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1339/2860] Processing: 061_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1340/2860] Processing: 061_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1341/2860] Processing: 061_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1342/2860] Processing: 061_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1343/2860] Processing: 062_cam1_1.jpg
# 	detect 1 faces
# [1344/2860] Processing: 062_cam1_2.jpg
# 	detect 1 faces
# [1345/2860] Processing: 062_cam1_3.jpg
# 	detect 1 faces
# [1346/2860] Processing: 062_cam2_1.jpg
# 	detect 1 faces
# [1347/2860] Processing: 062_cam2_2.jpg
# 	detect 1 faces
# [1348/2860] Processing: 062_cam2_3.jpg
# 	detect 1 faces
# [1349/2860] Processing: 062_cam3_1.jpg
# 	detect 1 faces
# [1350/2860] Processing: 062_cam3_2.jpg
# 	detect 1 faces
# [1351/2860] Processing: 062_cam3_3.jpg
# 	detect 1 faces
# [1352/2860] Processing: 062_cam4_1.jpg
# 	detect 1 faces
# [1353/2860] Processing: 062_cam4_2.jpg
# 	detect 1 faces
# [1354/2860] Processing: 062_cam4_3.jpg
# 	detect 1 faces
# [1355/2860] Processing: 062_cam5_1.jpg
# 	detect 1 faces
# [1356/2860] Processing: 062_cam5_2.jpg
# 	detect 1 faces
# [1357/2860] Processing: 062_cam5_3.jpg
# 	detect 1 faces
# [1358/2860] Processing: 062_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1359/2860] Processing: 062_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1360/2860] Processing: 062_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1361/2860] Processing: 062_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1362/2860] Processing: 062_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1363/2860] Processing: 062_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1364/2860] Processing: 062_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1365/2860] Processing: 063_cam1_1.jpg
# 	detect 1 faces
# [1366/2860] Processing: 063_cam1_2.jpg
# 	detect 1 faces
# [1367/2860] Processing: 063_cam1_3.jpg
# 	detect 1 faces
# [1368/2860] Processing: 063_cam2_1.jpg
# 	detect 1 faces
# [1369/2860] Processing: 063_cam2_2.jpg
# 	detect 1 faces
# [1370/2860] Processing: 063_cam2_3.jpg
# 	detect 1 faces
# [1371/2860] Processing: 063_cam3_1.jpg
# 	detect 1 faces
# [1372/2860] Processing: 063_cam3_2.jpg
# 	detect 1 faces
# [1373/2860] Processing: 063_cam3_3.jpg
# 	detect 1 faces
# [1374/2860] Processing: 063_cam4_1.jpg
# 	detect 1 faces
# [1375/2860] Processing: 063_cam4_2.jpg
# 	detect 1 faces
# [1376/2860] Processing: 063_cam4_3.jpg
# 	detect 1 faces
# [1377/2860] Processing: 063_cam5_1.jpg
# 	detect 1 faces
# [1378/2860] Processing: 063_cam5_2.jpg
# 	detect 1 faces
# [1379/2860] Processing: 063_cam5_3.jpg
# 	detect 1 faces
# [1380/2860] Processing: 063_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1381/2860] Processing: 063_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1382/2860] Processing: 063_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1383/2860] Processing: 063_cam7_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1384/2860] Processing: 063_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1385/2860] Processing: 063_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1386/2860] Processing: 063_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1387/2860] Processing: 064_cam1_1.jpg
# 	detect 1 faces
# [1388/2860] Processing: 064_cam1_2.jpg
# 	detect 1 faces
# [1389/2860] Processing: 064_cam1_3.jpg
# 	detect 1 faces
# [1390/2860] Processing: 064_cam2_1.jpg
# 	detect 1 faces
# [1391/2860] Processing: 064_cam2_2.jpg
# 	detect 1 faces
# [1392/2860] Processing: 064_cam2_3.jpg
# 	detect 1 faces
# [1393/2860] Processing: 064_cam3_1.jpg
# 	detect 1 faces
# [1394/2860] Processing: 064_cam3_2.jpg
# 	detect 1 faces
# [1395/2860] Processing: 064_cam3_3.jpg
# 	detect 1 faces
# [1396/2860] Processing: 064_cam4_1.jpg
# 	detect 1 faces
# [1397/2860] Processing: 064_cam4_2.jpg
# 	detect 1 faces
# [1398/2860] Processing: 064_cam4_3.jpg
# 	detect 1 faces
# [1399/2860] Processing: 064_cam5_1.jpg
# 	detect 1 faces
# [1400/2860] Processing: 064_cam5_2.jpg
# 	detect 1 faces
# [1401/2860] Processing: 064_cam5_3.jpg
# 	detect 1 faces
# [1402/2860] Processing: 064_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1403/2860] Processing: 064_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1404/2860] Processing: 064_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1405/2860] Processing: 064_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1406/2860] Processing: 064_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1407/2860] Processing: 064_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1408/2860] Processing: 064_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1409/2860] Processing: 065_cam1_1.jpg
# 	detect 1 faces
# [1410/2860] Processing: 065_cam1_2.jpg
# 	detect 1 faces
# [1411/2860] Processing: 065_cam1_3.jpg
# 	detect 1 faces
# [1412/2860] Processing: 065_cam2_1.jpg
# 	detect 1 faces
# [1413/2860] Processing: 065_cam2_2.jpg
# 	detect 1 faces
# [1414/2860] Processing: 065_cam2_3.jpg
# 	detect 1 faces
# [1415/2860] Processing: 065_cam3_1.jpg
# 	detect 1 faces
# [1416/2860] Processing: 065_cam3_2.jpg
# 	detect 1 faces
# [1417/2860] Processing: 065_cam3_3.jpg
# 	detect 1 faces
# [1418/2860] Processing: 065_cam4_1.jpg
# 	detect 1 faces
# [1419/2860] Processing: 065_cam4_2.jpg
# 	detect 1 faces
# [1420/2860] Processing: 065_cam4_3.jpg
# 	detect 1 faces
# [1421/2860] Processing: 065_cam5_1.jpg
# 	detect 1 faces
# [1422/2860] Processing: 065_cam5_2.jpg
# 	detect 1 faces
# [1423/2860] Processing: 065_cam5_3.jpg
# 	detect 1 faces
# [1424/2860] Processing: 065_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1425/2860] Processing: 065_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1426/2860] Processing: 065_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1427/2860] Processing: 065_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1428/2860] Processing: 065_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1429/2860] Processing: 065_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1430/2860] Processing: 065_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1431/2860] Processing: 066_cam1_1.jpg
# 	detect 1 faces
# [1432/2860] Processing: 066_cam1_2.jpg
# 	detect 1 faces
# [1433/2860] Processing: 066_cam1_3.jpg
# 	detect 1 faces
# [1434/2860] Processing: 066_cam2_1.jpg
# 	detect 1 faces
# [1435/2860] Processing: 066_cam2_2.jpg
# 	detect 1 faces
# [1436/2860] Processing: 066_cam2_3.jpg
# 	detect 1 faces
# [1437/2860] Processing: 066_cam3_1.jpg
# 	detect 1 faces
# [1438/2860] Processing: 066_cam3_2.jpg
# 	detect 1 faces
# [1439/2860] Processing: 066_cam3_3.jpg
# 	detect 1 faces
# [1440/2860] Processing: 066_cam4_1.jpg
# 	detect 1 faces
# [1441/2860] Processing: 066_cam4_2.jpg
# 	detect 1 faces
# [1442/2860] Processing: 066_cam4_3.jpg
# 	detect 1 faces
# [1443/2860] Processing: 066_cam5_1.jpg
# 	detect 1 faces
# [1444/2860] Processing: 066_cam5_2.jpg
# 	detect 1 faces
# [1445/2860] Processing: 066_cam5_3.jpg
# 	detect 1 faces
# [1446/2860] Processing: 066_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1447/2860] Processing: 066_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1448/2860] Processing: 066_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1449/2860] Processing: 066_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1450/2860] Processing: 066_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1451/2860] Processing: 066_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1452/2860] Processing: 066_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1453/2860] Processing: 067_cam1_1.jpg
# 	detect 1 faces
# [1454/2860] Processing: 067_cam1_2.jpg
# 	detect 1 faces
# [1455/2860] Processing: 067_cam1_3.jpg
# 	detect 1 faces
# [1456/2860] Processing: 067_cam2_1.jpg
# 	detect 1 faces
# [1457/2860] Processing: 067_cam2_2.jpg
# 	detect 1 faces
# [1458/2860] Processing: 067_cam2_3.jpg
# 	detect 1 faces
# [1459/2860] Processing: 067_cam3_1.jpg
# 	detect 1 faces
# [1460/2860] Processing: 067_cam3_2.jpg
# 	detect 1 faces
# [1461/2860] Processing: 067_cam3_3.jpg
# 	detect 1 faces
# [1462/2860] Processing: 067_cam4_1.jpg
# 	detect 1 faces
# [1463/2860] Processing: 067_cam4_2.jpg
# 	detect 1 faces
# [1464/2860] Processing: 067_cam4_3.jpg
# 	detect 1 faces
# [1465/2860] Processing: 067_cam5_1.jpg
# 	detect 1 faces
# [1466/2860] Processing: 067_cam5_2.jpg
# 	detect 1 faces
# [1467/2860] Processing: 067_cam5_3.jpg
# 	detect 1 faces
# [1468/2860] Processing: 067_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1469/2860] Processing: 067_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1470/2860] Processing: 067_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1471/2860] Processing: 067_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1472/2860] Processing: 067_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1473/2860] Processing: 067_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1474/2860] Processing: 067_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1475/2860] Processing: 068_cam1_1.jpg
# 	detect 1 faces
# [1476/2860] Processing: 068_cam1_2.jpg
# 	detect 1 faces
# [1477/2860] Processing: 068_cam1_3.jpg
# 	detect 1 faces
# [1478/2860] Processing: 068_cam2_1.jpg
# 	detect 1 faces
# [1479/2860] Processing: 068_cam2_2.jpg
# 	detect 1 faces
# [1480/2860] Processing: 068_cam2_3.jpg
# 	detect 1 faces
# [1481/2860] Processing: 068_cam3_1.jpg
# 	detect 1 faces
# [1482/2860] Processing: 068_cam3_2.jpg
# 	detect 1 faces
# [1483/2860] Processing: 068_cam3_3.jpg
# 	detect 1 faces
# [1484/2860] Processing: 068_cam4_1.jpg
# 	detect 1 faces
# [1485/2860] Processing: 068_cam4_2.jpg
# 	detect 1 faces
# [1486/2860] Processing: 068_cam4_3.jpg
# 	detect 1 faces
# [1487/2860] Processing: 068_cam5_1.jpg
# 	detect 1 faces
# [1488/2860] Processing: 068_cam5_2.jpg
# 	detect 1 faces
# [1489/2860] Processing: 068_cam5_3.jpg
# 	detect 1 faces
# [1490/2860] Processing: 068_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [1491/2860] Processing: 068_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1492/2860] Processing: 068_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1493/2860] Processing: 068_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1494/2860] Processing: 068_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1495/2860] Processing: 068_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1496/2860] Processing: 068_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1497/2860] Processing: 069_cam1_1.jpg
# 	detect 1 faces
# [1498/2860] Processing: 069_cam1_2.jpg
# 	detect 1 faces
# [1499/2860] Processing: 069_cam1_3.jpg
# 	detect 1 faces
# [1500/2860] Processing: 069_cam2_1.jpg
# 	detect 1 faces
# [1501/2860] Processing: 069_cam2_2.jpg
# 	detect 1 faces
# [1502/2860] Processing: 069_cam2_3.jpg
# 	detect 1 faces
# [1503/2860] Processing: 069_cam3_1.jpg
# 	detect 1 faces
# [1504/2860] Processing: 069_cam3_2.jpg
# 	detect 1 faces
# [1505/2860] Processing: 069_cam3_3.jpg
# 	detect 1 faces
# [1506/2860] Processing: 069_cam4_1.jpg
# 	detect 1 faces
# [1507/2860] Processing: 069_cam4_2.jpg
# 	detect 1 faces
# [1508/2860] Processing: 069_cam4_3.jpg
# 	detect 1 faces
# [1509/2860] Processing: 069_cam5_1.jpg
# 	detect 1 faces
# [1510/2860] Processing: 069_cam5_2.jpg
# 	detect 1 faces
# [1511/2860] Processing: 069_cam5_3.jpg
# 	detect 1 faces
# [1512/2860] Processing: 069_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1513/2860] Processing: 069_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1514/2860] Processing: 069_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1515/2860] Processing: 069_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1516/2860] Processing: 069_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1517/2860] Processing: 069_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1518/2860] Processing: 069_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1519/2860] Processing: 070_cam1_1.jpg
# 	detect 1 faces
# [1520/2860] Processing: 070_cam1_2.jpg
# 	detect 1 faces
# [1521/2860] Processing: 070_cam1_3.jpg
# 	detect 1 faces
# [1522/2860] Processing: 070_cam2_1.jpg
# 	detect 1 faces
# [1523/2860] Processing: 070_cam2_2.jpg
# 	detect 1 faces
# [1524/2860] Processing: 070_cam2_3.jpg
# 	detect 1 faces
# [1525/2860] Processing: 070_cam3_1.jpg
# 	detect 1 faces
# [1526/2860] Processing: 070_cam3_2.jpg
# 	detect 1 faces
# [1527/2860] Processing: 070_cam3_3.jpg
# 	detect 1 faces
# [1528/2860] Processing: 070_cam4_1.jpg
# 	detect 1 faces
# [1529/2860] Processing: 070_cam4_2.jpg
# 	detect 1 faces
# [1530/2860] Processing: 070_cam4_3.jpg
# 	detect 1 faces
# [1531/2860] Processing: 070_cam5_1.jpg
# 	detect 1 faces
# [1532/2860] Processing: 070_cam5_2.jpg
# 	detect 1 faces
# [1533/2860] Processing: 070_cam5_3.jpg
# 	detect 1 faces
# [1534/2860] Processing: 070_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1535/2860] Processing: 070_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1536/2860] Processing: 070_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1537/2860] Processing: 070_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [1538/2860] Processing: 070_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [1539/2860] Processing: 070_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [1540/2860] Processing: 070_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [1541/2860] Processing: 071_cam1_1.jpg
# 	detect 1 faces
# [1542/2860] Processing: 071_cam1_2.jpg
# 	detect 1 faces
# [1543/2860] Processing: 071_cam1_3.jpg
# 	detect 1 faces
# [1544/2860] Processing: 071_cam2_1.jpg
# 	detect 1 faces
# [1545/2860] Processing: 071_cam2_2.jpg
# 	detect 1 faces
# [1546/2860] Processing: 071_cam2_3.jpg
# 	detect 1 faces
# [1547/2860] Processing: 071_cam3_1.jpg
# 	detect 1 faces
# [1548/2860] Processing: 071_cam3_2.jpg
# 	detect 1 faces
# [1549/2860] Processing: 071_cam3_3.jpg
# 	detect 1 faces
# [1550/2860] Processing: 071_cam4_1.jpg
# 	detect 1 faces
# [1551/2860] Processing: 071_cam4_2.jpg
# 	detect 1 faces
# [1552/2860] Processing: 071_cam4_3.jpg
# 	detect 1 faces
# [1553/2860] Processing: 071_cam5_1.jpg
# ...
# Grayscale input: True
# 	detect 1 faces
# [2618/2860] Processing: 119_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2619/2860] Processing: 120_cam1_1.jpg
# 	detect 1 faces
# [2620/2860] Processing: 120_cam1_2.jpg
# 	detect 1 faces
# [2621/2860] Processing: 120_cam1_3.jpg
# 	detect 1 faces
# [2622/2860] Processing: 120_cam2_1.jpg
# 	detect 1 faces
# [2623/2860] Processing: 120_cam2_2.jpg
# 	detect 1 faces
# [2624/2860] Processing: 120_cam2_3.jpg
# 	detect 1 faces
# [2625/2860] Processing: 120_cam3_1.jpg
# 	detect 1 faces
# [2626/2860] Processing: 120_cam3_2.jpg
# 	detect 1 faces
# [2627/2860] Processing: 120_cam3_3.jpg
# 	detect 1 faces
# [2628/2860] Processing: 120_cam4_1.jpg
# 	detect 1 faces
# [2629/2860] Processing: 120_cam4_2.jpg
# 	detect 1 faces
# [2630/2860] Processing: 120_cam4_3.jpg
# 	detect 1 faces
# [2631/2860] Processing: 120_cam5_1.jpg
# 	detect 1 faces
# [2632/2860] Processing: 120_cam5_2.jpg
# 	detect 1 faces
# [2633/2860] Processing: 120_cam5_3.jpg
# 	detect 1 faces
# [2634/2860] Processing: 120_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2635/2860] Processing: 120_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2636/2860] Processing: 120_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2637/2860] Processing: 120_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2638/2860] Processing: 120_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2639/2860] Processing: 120_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2640/2860] Processing: 120_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2641/2860] Processing: 121_cam1_1.jpg
# 	detect 1 faces
# [2642/2860] Processing: 121_cam1_2.jpg
# 	detect 1 faces
# [2643/2860] Processing: 121_cam1_3.jpg
# 	detect 1 faces
# [2644/2860] Processing: 121_cam2_1.jpg
# 	detect 1 faces
# [2645/2860] Processing: 121_cam2_2.jpg
# 	detect 1 faces
# [2646/2860] Processing: 121_cam2_3.jpg
# 	detect 1 faces
# [2647/2860] Processing: 121_cam3_1.jpg
# 	detect 1 faces
# [2648/2860] Processing: 121_cam3_2.jpg
# 	detect 1 faces
# [2649/2860] Processing: 121_cam3_3.jpg
# 	detect 1 faces
# [2650/2860] Processing: 121_cam4_1.jpg
# 	detect 1 faces
# [2651/2860] Processing: 121_cam4_2.jpg
# 	detect 1 faces
# [2652/2860] Processing: 121_cam4_3.jpg
# 	detect 1 faces
# [2653/2860] Processing: 121_cam5_1.jpg
# 	detect 1 faces
# [2654/2860] Processing: 121_cam5_2.jpg
# 	detect 1 faces
# [2655/2860] Processing: 121_cam5_3.jpg
# 	detect 1 faces
# [2656/2860] Processing: 121_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [2657/2860] Processing: 121_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2658/2860] Processing: 121_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2659/2860] Processing: 121_cam7_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [2660/2860] Processing: 121_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2661/2860] Processing: 121_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2662/2860] Processing: 121_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2663/2860] Processing: 122_cam1_1.jpg
# 	detect 1 faces
# [2664/2860] Processing: 122_cam1_2.jpg
# 	detect 1 faces
# [2665/2860] Processing: 122_cam1_3.jpg
# 	detect 1 faces
# [2666/2860] Processing: 122_cam2_1.jpg
# 	detect 1 faces
# [2667/2860] Processing: 122_cam2_2.jpg
# 	detect 1 faces
# [2668/2860] Processing: 122_cam2_3.jpg
# 	detect 1 faces
# [2669/2860] Processing: 122_cam3_1.jpg
# 	detect 1 faces
# [2670/2860] Processing: 122_cam3_2.jpg
# 	detect 1 faces
# [2671/2860] Processing: 122_cam3_3.jpg
# 	detect 1 faces
# [2672/2860] Processing: 122_cam4_1.jpg
# 	detect 1 faces
# [2673/2860] Processing: 122_cam4_2.jpg
# 	detect 1 faces
# [2674/2860] Processing: 122_cam4_3.jpg
# 	detect 1 faces
# [2675/2860] Processing: 122_cam5_1.jpg
# 	detect 1 faces
# [2676/2860] Processing: 122_cam5_2.jpg
# 	detect 1 faces
# [2677/2860] Processing: 122_cam5_3.jpg
# 	detect 1 faces
# [2678/2860] Processing: 122_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2679/2860] Processing: 122_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2680/2860] Processing: 122_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2681/2860] Processing: 122_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2682/2860] Processing: 122_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2683/2860] Processing: 122_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2684/2860] Processing: 122_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2685/2860] Processing: 123_cam1_1.jpg
# 	detect 1 faces
# [2686/2860] Processing: 123_cam1_2.jpg
# 	detect 1 faces
# [2687/2860] Processing: 123_cam1_3.jpg
# 	detect 1 faces
# [2688/2860] Processing: 123_cam2_1.jpg
# 	detect 1 faces
# [2689/2860] Processing: 123_cam2_2.jpg
# 	detect 1 faces
# [2690/2860] Processing: 123_cam2_3.jpg
# 	detect 1 faces
# [2691/2860] Processing: 123_cam3_1.jpg
# 	detect 1 faces
# [2692/2860] Processing: 123_cam3_2.jpg
# 	detect 1 faces
# [2693/2860] Processing: 123_cam3_3.jpg
# 	detect 1 faces
# [2694/2860] Processing: 123_cam4_1.jpg
# 	detect 1 faces
# [2695/2860] Processing: 123_cam4_2.jpg
# 	detect 1 faces
# [2696/2860] Processing: 123_cam4_3.jpg
# 	detect 1 faces
# [2697/2860] Processing: 123_cam5_1.jpg
# 	detect 1 faces
# [2698/2860] Processing: 123_cam5_2.jpg
# 	detect 1 faces
# [2699/2860] Processing: 123_cam5_3.jpg
# 	detect 1 faces
# [2700/2860] Processing: 123_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2701/2860] Processing: 123_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2702/2860] Processing: 123_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2703/2860] Processing: 123_cam7_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [2704/2860] Processing: 123_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2705/2860] Processing: 123_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2706/2860] Processing: 123_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2707/2860] Processing: 124_cam1_1.jpg
# 	detect 1 faces
# [2708/2860] Processing: 124_cam1_2.jpg
# 	detect 1 faces
# [2709/2860] Processing: 124_cam1_3.jpg
# 	detect 1 faces
# [2710/2860] Processing: 124_cam2_1.jpg
# 	detect 1 faces
# [2711/2860] Processing: 124_cam2_2.jpg
# 	detect 1 faces
# [2712/2860] Processing: 124_cam2_3.jpg
# 	detect 1 faces
# [2713/2860] Processing: 124_cam3_1.jpg
# 	detect 1 faces
# [2714/2860] Processing: 124_cam3_2.jpg
# 	detect 1 faces
# [2715/2860] Processing: 124_cam3_3.jpg
# 	detect 1 faces
# [2716/2860] Processing: 124_cam4_1.jpg
# 	detect 1 faces
# [2717/2860] Processing: 124_cam4_2.jpg
# 	detect 1 faces
# [2718/2860] Processing: 124_cam4_3.jpg
# 	detect 1 faces
# [2719/2860] Processing: 124_cam5_1.jpg
# 	detect 1 faces
# [2720/2860] Processing: 124_cam5_2.jpg
# 	detect 1 faces
# [2721/2860] Processing: 124_cam5_3.jpg
# 	detect 1 faces
# [2722/2860] Processing: 124_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2723/2860] Processing: 124_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2724/2860] Processing: 124_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2725/2860] Processing: 124_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2726/2860] Processing: 124_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2727/2860] Processing: 124_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2728/2860] Processing: 124_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2729/2860] Processing: 125_cam1_1.jpg
# 	detect 1 faces
# [2730/2860] Processing: 125_cam1_2.jpg
# 	detect 1 faces
# [2731/2860] Processing: 125_cam1_3.jpg
# 	detect 1 faces
# [2732/2860] Processing: 125_cam2_1.jpg
# 	detect 1 faces
# [2733/2860] Processing: 125_cam2_2.jpg
# 	detect 1 faces
# [2734/2860] Processing: 125_cam2_3.jpg
# 	detect 1 faces
# [2735/2860] Processing: 125_cam3_1.jpg
# 	detect 1 faces
# [2736/2860] Processing: 125_cam3_2.jpg
# 	detect 1 faces
# [2737/2860] Processing: 125_cam3_3.jpg
# 	detect 1 faces
# [2738/2860] Processing: 125_cam4_1.jpg
# 	detect 1 faces
# [2739/2860] Processing: 125_cam4_2.jpg
# 	detect 1 faces
# [2740/2860] Processing: 125_cam4_3.jpg
# 	detect 1 faces
# [2741/2860] Processing: 125_cam5_1.jpg
# 	detect 1 faces
# [2742/2860] Processing: 125_cam5_2.jpg
# 	detect 1 faces
# [2743/2860] Processing: 125_cam5_3.jpg
# 	detect 1 faces
# [2744/2860] Processing: 125_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [2745/2860] Processing: 125_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2746/2860] Processing: 125_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2747/2860] Processing: 125_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2748/2860] Processing: 125_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2749/2860] Processing: 125_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2750/2860] Processing: 125_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2751/2860] Processing: 126_cam1_1.jpg
# 	detect 1 faces
# [2752/2860] Processing: 126_cam1_2.jpg
# 	detect 1 faces
# [2753/2860] Processing: 126_cam1_3.jpg
# 	detect 1 faces
# [2754/2860] Processing: 126_cam2_1.jpg
# 	detect 1 faces
# [2755/2860] Processing: 126_cam2_2.jpg
# 	detect 1 faces
# [2756/2860] Processing: 126_cam2_3.jpg
# 	detect 1 faces
# [2757/2860] Processing: 126_cam3_1.jpg
# 	detect 1 faces
# [2758/2860] Processing: 126_cam3_2.jpg
# 	detect 1 faces
# [2759/2860] Processing: 126_cam3_3.jpg
# 	detect 1 faces
# [2760/2860] Processing: 126_cam4_1.jpg
# 	detect 1 faces
# [2761/2860] Processing: 126_cam4_2.jpg
# 	detect 1 faces
# [2762/2860] Processing: 126_cam4_3.jpg
# 	detect 1 faces
# [2763/2860] Processing: 126_cam5_1.jpg
# 	detect 1 faces
# [2764/2860] Processing: 126_cam5_2.jpg
# 	detect 1 faces
# [2765/2860] Processing: 126_cam5_3.jpg
# 	detect 1 faces
# [2766/2860] Processing: 126_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2767/2860] Processing: 126_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2768/2860] Processing: 126_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2769/2860] Processing: 126_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2770/2860] Processing: 126_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2771/2860] Processing: 126_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2772/2860] Processing: 126_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2773/2860] Processing: 127_cam1_1.jpg
# 	detect 1 faces
# [2774/2860] Processing: 127_cam1_2.jpg
# 	detect 1 faces
# [2775/2860] Processing: 127_cam1_3.jpg
# 	detect 1 faces
# [2776/2860] Processing: 127_cam2_1.jpg
# 	detect 1 faces
# [2777/2860] Processing: 127_cam2_2.jpg
# 	detect 1 faces
# [2778/2860] Processing: 127_cam2_3.jpg
# 	detect 1 faces
# [2779/2860] Processing: 127_cam3_1.jpg
# 	detect 1 faces
# [2780/2860] Processing: 127_cam3_2.jpg
# 	detect 1 faces
# [2781/2860] Processing: 127_cam3_3.jpg
# 	detect 1 faces
# [2782/2860] Processing: 127_cam4_1.jpg
# 	detect 1 faces
# [2783/2860] Processing: 127_cam4_2.jpg
# 	detect 1 faces
# [2784/2860] Processing: 127_cam4_3.jpg
# 	detect 1 faces
# [2785/2860] Processing: 127_cam5_1.jpg
# 	detect 1 faces
# [2786/2860] Processing: 127_cam5_2.jpg
# 	detect 1 faces
# [2787/2860] Processing: 127_cam5_3.jpg
# 	detect 1 faces
# [2788/2860] Processing: 127_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2789/2860] Processing: 127_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2790/2860] Processing: 127_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2791/2860] Processing: 127_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2792/2860] Processing: 127_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2793/2860] Processing: 127_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2794/2860] Processing: 127_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2795/2860] Processing: 128_cam1_1.jpg
# 	detect 1 faces
# [2796/2860] Processing: 128_cam1_2.jpg
# 	detect 1 faces
# [2797/2860] Processing: 128_cam1_3.jpg
# 	detect 1 faces
# [2798/2860] Processing: 128_cam2_1.jpg
# 	detect 1 faces
# [2799/2860] Processing: 128_cam2_2.jpg
# 	detect 1 faces
# [2800/2860] Processing: 128_cam2_3.jpg
# 	detect 1 faces
# [2801/2860] Processing: 128_cam3_1.jpg
# 	detect 1 faces
# [2802/2860] Processing: 128_cam3_2.jpg
# 	detect 1 faces
# [2803/2860] Processing: 128_cam3_3.jpg
# 	detect 1 faces
# [2804/2860] Processing: 128_cam4_1.jpg
# 	detect 1 faces
# [2805/2860] Processing: 128_cam4_2.jpg
# 	detect 1 faces
# [2806/2860] Processing: 128_cam4_3.jpg
# 	detect 1 faces
# [2807/2860] Processing: 128_cam5_1.jpg
# 	detect 1 faces
# [2808/2860] Processing: 128_cam5_2.jpg
# 	detect 1 faces
# [2809/2860] Processing: 128_cam5_3.jpg
# 	detect 1 faces
# [2810/2860] Processing: 128_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2811/2860] Processing: 128_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2812/2860] Processing: 128_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2813/2860] Processing: 128_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2814/2860] Processing: 128_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2815/2860] Processing: 128_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2816/2860] Processing: 128_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2817/2860] Processing: 129_cam1_1.jpg
# 	detect 1 faces
# [2818/2860] Processing: 129_cam1_2.jpg
# 	detect 1 faces
# [2819/2860] Processing: 129_cam1_3.jpg
# 	detect 1 faces
# [2820/2860] Processing: 129_cam2_1.jpg
# 	detect 1 faces
# [2821/2860] Processing: 129_cam2_2.jpg
# 	detect 1 faces
# [2822/2860] Processing: 129_cam2_3.jpg
# 	detect 1 faces
# [2823/2860] Processing: 129_cam3_1.jpg
# 	detect 1 faces
# [2824/2860] Processing: 129_cam3_2.jpg
# 	detect 1 faces
# [2825/2860] Processing: 129_cam3_3.jpg
# 	detect 1 faces
# [2826/2860] Processing: 129_cam4_1.jpg
# 	detect 1 faces
# [2827/2860] Processing: 129_cam4_2.jpg
# 	detect 1 faces
# [2828/2860] Processing: 129_cam4_3.jpg
# 	detect 1 faces
# [2829/2860] Processing: 129_cam5_1.jpg
# 	detect 1 faces
# [2830/2860] Processing: 129_cam5_2.jpg
# 	detect 1 faces
# [2831/2860] Processing: 129_cam5_3.jpg
# 	detect 1 faces
# [2832/2860] Processing: 129_cam6_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2833/2860] Processing: 129_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2834/2860] Processing: 129_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2835/2860] Processing: 129_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2836/2860] Processing: 129_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2837/2860] Processing: 129_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2838/2860] Processing: 129_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2839/2860] Processing: 130_cam1_1.jpg
# 	detect 1 faces
# [2840/2860] Processing: 130_cam1_2.jpg
# 	detect 1 faces
# [2841/2860] Processing: 130_cam1_3.jpg
# 	detect 1 faces
# [2842/2860] Processing: 130_cam2_1.jpg
# 	detect 1 faces
# [2843/2860] Processing: 130_cam2_2.jpg
# 	detect 1 faces
# [2844/2860] Processing: 130_cam2_3.jpg
# 	detect 1 faces
# [2845/2860] Processing: 130_cam3_1.jpg
# 	detect 1 faces
# [2846/2860] Processing: 130_cam3_2.jpg
# 	detect 1 faces
# [2847/2860] Processing: 130_cam3_3.jpg
# 	detect 1 faces
# [2848/2860] Processing: 130_cam4_1.jpg
# 	detect 1 faces
# [2849/2860] Processing: 130_cam4_2.jpg
# 	detect 1 faces
# [2850/2860] Processing: 130_cam4_3.jpg
# 	detect 1 faces
# [2851/2860] Processing: 130_cam5_1.jpg
# 	detect 1 faces
# [2852/2860] Processing: 130_cam5_2.jpg
# 	detect 1 faces
# [2853/2860] Processing: 130_cam5_3.jpg
# 	detect 1 faces
# [2854/2860] Processing: 130_cam6_1.jpg
# Grayscale input: True
# 	detect 0 faces
# [2855/2860] Processing: 130_cam6_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2856/2860] Processing: 130_cam6_3.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
# [2857/2860] Processing: 130_cam7_1.jpg
# Grayscale input: True
# 	detect 1 faces
# [2858/2860] Processing: 130_cam7_2.jpg
# Grayscale input: True
# 	detect 1 faces
# [2859/2860] Processing: 130_cam7_3.jpg
# Grayscale input: True
# 	detect 1 faces
# [2860/2860] Processing: 130_cam8.jpg
# Grayscale input: True
# 	detect 1 faces
# 	Input is a 16-bit image
#
# All results are saved in /content/scface_data/SCface_database/surveillance_cameras_all_restored

# %% [markdown]
# ## 3.2 Classe do Dataset

# %%
# Classe de Dataset para o SCface
class ScfaceDatasetWithMTCNN(Dataset):
  """Classe que representa uma adaptação de Dataset do Pytorch para o SCface e o
  uso da MTCNN. Esta classe utiliza a arquitetura MTCNN para detecção e alinha
  mento.
  """

  def __init__(self, filepaths, labels, transform=None, mtcnn_model=None):
    """Inicializa o Dataset adaptado para o SCface com suporte à detecção facial
    via MTCNN.

    Args:
      filepaths (list[str]): Lista de caminhos das imagens.
      labels (list[str]): Lista de rótulos correspondentes a cada
      imagem.
      transform (albumentations.Compose, opcional): Conjunto de transformações
      para as imagens (padrão é None).
      mtcnn_model (facenet_pytorch.MTCNN, opcional): Instância do modelo MTCNN
      (padrão é None).
    """
    self.filepaths, self.labels = filepaths, labels
    self.transform = transform
    self.mtcnn = mtcnn_model

  def __len__(self):
    """Returns:
        int: Número total de amostras no dataset."
    """
    return len(self.filepaths)

  def __getitem__(self, idx):
    """Obtém a amostra com índice "idx" indicado.

    Args:
      idx (int): Índice de uma imagem

    Returns:
      tuple (torch.tensor, int or str, str): img_tensor, label, str(img_path)
      ou None, caso haja algum erro
    """
    img_path, label = self.filepaths[idx], self.labels[idx]

    try:
      img_pil = Image.open(img_path).convert("RGB")
    except Exception as e:
      print(f"Erro ao carregar a imagem: {img_path}. Erro: {e}")

      return None

    # Detecção e alinhamento com MTCNN
    face_tensor = self.mtcnn(img_pil)

    if face_tensor is None:
      return None

    # O tensor do MTCNN está normalizado em [-1, 1]. Para Albumentations,
    # vamos convertê-lo de volta para uma imagem NumPy [0, 255]
    face_tensor = (face_tensor + 1) / 2.0

    img_np = face_tensor.permute(1, 2, 0).cpu().numpy() * 255.0

    img_np = img_np.astype(np.uint8)

    # Aplicar as transformações da Albumentations
    if self.transform:
      augmented = self.transform(image=img_np)

      img_tensor = augmented['image']

    return img_tensor, label, str(img_path)

# %%
# Função Collate para lidar com amostras nas quais nenhum rostos é detectado
def collate_fn_skip_none(batch):
  """ Função Collate para o Dataloader que ignora amostras inválidas, aquelas em
  que nenhum rosto é detectado.

  Args:
    batch (list): Lista de amostras.

  Returns:
    tuple or None:
      - Se houver amostras válidas: retorna o batch processado pelo
        `torch.utils.data.dataloader.default_collate`.
      - Se todas as amostras forem inválidas: retorna `(None, None, None)`.
  """
  # Filtra qualquer amostra na qual o MTCNN falhou
  batch = [item for item in batch if item is not None]

  if not batch: # Se o batch inteiro for None
    return None, None, None

  # Desempacota o batch filtrado e o retorna
  return torch.utils.data.dataloader.default_collate(batch)

# %% [markdown]
# ## 3.3 Criação dos Datasets e DataLoaders

# %%
# Criar o mapa de rótulos unificado a partir da galeria
# A gallery geralmente contém todas as identidades que podem aparecer nas sondas.
print("Criando mapa de rótulos unificado a partir da galeria...")

all_ids_str = sorted(list(set([re.match(r'(\d+)', f.name).group(1) for f in all_gallery_filepaths])))

unified_label_map = {id_str: i for i, id_str in enumerate(all_ids_str)}

NUM_SCFACE_CLASSES = len(unified_label_map)

print(f"Mapa unificado criado com {NUM_SCFACE_CLASSES} identidades.")

# Carregar os dados da galeria
all_gallery_labels = [unified_label_map[re.match(r'(\d+)', f.name).group(1)] for f in all_gallery_filepaths]

print(f"Número total de amostras na galeria antes do filtro: {len(all_gallery_labels)}")

# Dividir a galeria em treino e validação (80/20) de forma estratificada
print("Dividindo dados de treino e validação...")
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)

train_indices, val_indices = next(splitter.split(all_gallery_filepaths, all_gallery_labels))
# Out:
# Criando mapa de rótulos unificado a partir da gallery...
# Mapa unificado criado com 130 identidades.
# Número total de amostras na galeria antes do filtro: 1170
# Dividindo dados de treino e validação...

# %%
# Criar os datasets de treino e validação
train_dataset = ScfaceDatasetWithMTCNN([all_gallery_filepaths[i] for i in train_indices],
                                       [all_gallery_labels[i] for i in train_indices],
                                       transform=train_transform,
                                       mtcnn_model=mtcnn)

val_dataset = ScfaceDatasetWithMTCNN([all_gallery_filepaths[i] for i in val_indices],
                                     [all_gallery_labels[i] for i in val_indices],
                                     transform=val_test_transform,
                                     mtcnn_model=mtcnn)

# %%
# Criar os DataLoaders de treino e validação
train_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          collate_fn=collate_fn_skip_none)

val_loader = DataLoader(val_dataset,
                        batch_size=BATCH_SIZE,
                        shuffle=False,
                        collate_fn=collate_fn_skip_none)

print(f"DataLoaders de treino ({len(train_dataset)} imgs) e validação ({len(val_dataset)} imgs) criados.")
# Out:
# DataLoaders de treino (936 imgs) e validação (234 imgs) criados.

# %%
# Criar o DataLoader de teste (sondas)
print("Criando DataLoader de teste (sondas)...")
probe_filepaths_all = list(Path("/content/scface_data/SCface_database/surveillance_cameras_all_restored/restored_faces").glob('*.png'))

probe_labels_all = [unified_label_map.get(re.match(r'(\d+)', p.name).group(1)) for p in probe_filepaths_all]

# Filtramos as imagens de sonda que não têm uma identidade correspondente na galeria
probe_data_filtered = [(fp, lbl) for fp, lbl in zip(probe_filepaths_all, probe_labels_all) if lbl is not None]
probe_filepaths, probe_labels = zip(*probe_data_filtered)

# Criamos o dataset e o dataloader apenas com as sondas válidas
probe_dataset = ScfaceDatasetWithMTCNN(list(probe_filepaths),
                                       list(probe_labels),
                                       transform=val_test_transform,
                                       mtcnn_model=mtcnn)

probe_loader = DataLoader(probe_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=False,
                          collate_fn=collate_fn_skip_none)

# Loader para a galeria completa
gallery_dataset_for_eval = ScfaceDatasetWithMTCNN(all_gallery_filepaths,
                                                  all_gallery_labels,
                                                  transform=val_test_transform,
                                                  mtcnn_model=mtcnn)

gallery_loader_for_eval = DataLoader(dataset=gallery_dataset_for_eval,
                                     batch_size=BATCH_SIZE,
                                     shuffle=False,
                                     collate_fn=collate_fn_skip_none)

print(f"DataLoader de teste ({len(probe_loader)} imgs) criado.")
print(f"DataLoader de teste ({len(gallery_loader_for_eval)} imgs) criado.")
# Out:
# Criando DataLoader de teste (sondas)...
# DataLoader de teste (88 imgs) criado.
# DataLoader de teste (37 imgs) criado.

# %% [markdown]
# # 4. Treinamento do Modelo

# %%
# Classe do ArcFace
class ArcFace(nn.Module):
  """Classe que representa a implementação do ArcFace.
  """

  def __init__(self, in_features, out_features, s=30.0, m=0.50):
    """Implementação do cabeçalho ArcFace para classificação com margem angular.

    Args:
      in_features (int): Dimensão dos embeddings de entrada.
      out_features (int): Número de classes.
      s (float, opcional): Fator de escala aplicado aos logits (padrão: 30.0).
      m (float, opcional): Margem angular aplicada à classe correta
      (padrão: 0.50).
    """

    super(ArcFace, self).__init__()

    self.in_features, self.out_features, self.s, self.m = in_features, out_features, s, m

    self.weight = nn.Parameter(torch.FloatTensor(out_features, in_features))

    nn.init.xavier_uniform_(self.weight)


  def forward(self, emb, lbl):
    """
    Executa a passagem direta do ArcFace.

    Args:
      emb (torch.Tensor): Tensor de embeddings normalizados de tamanho
          (batch_size, in_features).
      lbl (torch.Tensor): Tensor de rótulos de classe de tamanho (batch_size,).

    Returns:
      torch.Tensor: Logits com margem angular aplicada,
      prontos para função de perda.
    """
    cosine = F.linear(F.normalize(emb), F.normalize(self.weight))

    theta, one_hot = torch.acos(torch.clamp(cosine, -1, 1)), torch.zeros_like(cosine)

    one_hot.scatter_(1, lbl.view(-1, 1).long(), 1)

    output = self.s * ((one_hot * torch.cos(theta + self.m)) + ((1 - one_hot) * cosine))

    return output


# Classe do Modelo com ArcFace
class FaceRecognitionModelWithArcFace(nn.Module):
  """Modelo de reconhecimento facial que utiliza InceptionResnetV1 com ArcFace.
  """

  def __init__(self, num_classes, embedding_size=512):
    """Inicizaliza o modelo

    Args:
      num_classes (int): Número de classes (rótulos/labels)
      embedding_size: Tamanho dos embeddings gerados pelo modelo (padrão: 512).
    """

    super(FaceRecognitionModelWithArcFace, self).__init__()

    self.backbone = InceptionResnetV1(pretrained='vggface2', classify=False)

    self.head = ArcFace(in_features=embedding_size, out_features=num_classes)


  def forward(self, image, label):
    """Executa a passagem direta pelo modelo de reconhecimento facial

    Args:
      image (torch.Tensor): Batch da imagem, no formato (B, C, H, W).
      label (torch.Tensor): Tensor de rótulos de classe.

    Returns:
      torch.Tensor: Logits com margem angular aplicada pelo ArcFace.
    """

    embedding = self.backbone(image)

    logits = self.head(embedding, label)

    return logits

# %%
# Inicializando modelo
print("Inicializando novo modelo para fine-tuning no Scface...")

scface_model = FaceRecognitionModelWithArcFace(num_classes=NUM_SCFACE_CLASSES).to(device)
# Out:
# Inicializando novo modelo para fine-tuning no Scface...
#   0%|          | 0.00/107M [00:00<?, ?B/s]

# %%
# Declarando otimizador e loss
optimizer = optim.Adam(scface_model.parameters(), lr=LEARNING_RATE)

loss_fn = nn.CrossEntropyLoss()

# %%
print("Iniciando o processo de treinamento...")

best_val_loss = float('inf')

best_model_state = None

patience_counter = 0

early_stopping_patience = 10 # O treino para se a Val Loss não melhorar por 10 épocas seguidas

start_time_total_train = timer()

for epoch in range(EPOCHS):
    # Fase de Treinamento
    scface_model.train()

    running_loss_train = 0.0

    running_acc_train = 0.0

    train_batches = 0

    loop_train = tqdm(train_loader, desc=f"Epoch {epoch + 1}/{EPOCHS} [Treino]", leave=False)

    for images, labels, _ in loop_train:
      images, labels = images.to(device), labels.to(device)

      # 1. Forward pass com imagem e rótulo para o ArcFace
      logits = scface_model(images, labels)

      # 2. Calcular a perda
      loss = loss_fn(logits, labels)

      # 3. Zerar o gradiente do otimizador
      optimizer.zero_grad()

      # 4. Backpropagation
      loss.backward()

      # 5. Step do otimizador
      optimizer.step()

      # Acumular métricas
      running_loss_train += loss.item()
      preds = torch.argmax(logits, dim=1)
      running_acc_train += (preds == labels).float().mean().item()
      train_batches += 1
      loop_train.set_postfix(loss=loss.item())

    avg_loss_train = running_loss_train / train_batches

    avg_acc_train = running_acc_train / train_batches

    # Fase de Avaliação
    scface_model.eval()

    running_loss_val = 0.0

    running_acc_val = 0.0

    val_batches = 0

    with torch.inference_mode():
      loop_val = tqdm(val_loader, desc=f"Epoch {epoch + 1}/{EPOCHS} [Avaliação]", leave=False)

      for images, labels, _ in loop_val:
        images, labels = images.to(device), labels.to(device)

        # 1. Forward pass com imagem e rótulo
        logits = scface_model(images, labels)

        # 2. Calcular perda
        loss = loss_fn(logits, labels)
        running_loss_val += loss.item()

        # Calcular acurácia
        preds = torch.argmax(logits, dim=1)
        running_acc_val += (preds == labels).float().mean().item()
        val_batches += 1
        loop_val.set_postfix(val_loss=loss.item())

    avg_loss_val = running_loss_val / val_batches
    avg_acc_val = running_acc_val / val_batches

    print(f"Epoch {epoch+1}/{EPOCHS} | Treino Loss: {avg_loss_train:.4f}, Treino Acc: {avg_acc_train:.4f} | "
          f"Val Loss: {avg_loss_val:.4f}, Val Acc: {avg_acc_val:.4f}")

    # Lógica para salvar o melhor modelo e Early Stopping
    if avg_loss_val < best_val_loss:
      best_val_loss = avg_loss_val
      best_model_state = copy.deepcopy(scface_model.state_dict())
      patience_counter = 0
      print(f"  Novo melhor modelo encontrado! Val Loss: {best_val_loss:.4f}. Salvando estado...")
    else:
      patience_counter += 1

    if patience_counter >= early_stopping_patience:
      print(f"  Early stopping na Época {epoch + 1} pois a perda de validação não melhorou por {early_stopping_patience} épocas.")
      break

end_time_total_train = timer()

print(f"\nTempo total de treinamento: {end_time_total_train - start_time_total_train:.3f} segundos")

if best_model_state:
  print("Treinamento concluído. O melhor estado do modelo foi salvo na memória.")

  # Salvar o modelo final no disco
  torch.save(best_model_state, 'scface_best_model.pth')
  print("Melhor modelo salvo em 'scface_best_model.pth'")
else:
  print("Treinamento concluído, mas nenhum modelo foi salvo.")
# Out:
# Iniciando o processo de treinamento...
# Epoch 1/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 1/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 1/30 | Treino Loss: 19.6565, Treino Acc: 0.0000 | Val Loss: 18.5057, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 18.5057. Salvando estado...
# Epoch 2/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 2/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 2/30 | Treino Loss: 18.3077, Treino Acc: 0.0000 | Val Loss: 17.0858, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 17.0858. Salvando estado...
# Epoch 3/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 3/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 3/30 | Treino Loss: 17.2331, Treino Acc: 0.0000 | Val Loss: 15.9995, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 15.9995. Salvando estado...
# Epoch 4/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 4/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 4/30 | Treino Loss: 16.1605, Treino Acc: 0.0000 | Val Loss: 14.9057, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 14.9057. Salvando estado...
# Epoch 5/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 5/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5/30 | Treino Loss: 15.2452, Treino Acc: 0.0000 | Val Loss: 13.9703, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 13.9703. Salvando estado...
# Epoch 6/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 6/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 6/30 | Treino Loss: 14.4329, Treino Acc: 0.0000 | Val Loss: 13.2476, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 13.2476. Salvando estado...
# Epoch 7/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 7/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 7/30 | Treino Loss: 13.5969, Treino Acc: 0.0000 | Val Loss: 12.3002, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 12.3002. Salvando estado...
# Epoch 8/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 8/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 8/30 | Treino Loss: 12.8890, Treino Acc: 0.0000 | Val Loss: 11.5815, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 11.5815. Salvando estado...
# Epoch 9/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 9/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 9/30 | Treino Loss: 12.2030, Treino Acc: 0.0000 | Val Loss: 10.8487, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 10.8487. Salvando estado...
# Epoch 10/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 10/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 10/30 | Treino Loss: 11.4377, Treino Acc: 0.0000 | Val Loss: 10.0682, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 10.0682. Salvando estado...
# Epoch 11/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 11/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 11/30 | Treino Loss: 10.6619, Treino Acc: 0.0000 | Val Loss: 9.3568, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 9.3568. Salvando estado...
# Epoch 12/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 12/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 12/30 | Treino Loss: 10.1076, Treino Acc: 0.0000 | Val Loss: 8.6829, Val Acc: 0.0000
#   Novo melhor modelo encontrado! Val Loss: 8.6829. Salvando estado...
# Epoch 13/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 13/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 13/30 | Treino Loss: 9.2099, Treino Acc: 0.0000 | Val Loss: 8.0199, Val Acc: 0.0039
#   Novo melhor modelo encontrado! Val Loss: 8.0199. Salvando estado...
# Epoch 14/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 14/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 14/30 | Treino Loss: 8.6234, Treino Acc: 0.0010 | Val Loss: 7.2210, Val Acc: 0.0117
#   Novo melhor modelo encontrado! Val Loss: 7.2210. Salvando estado...
# Epoch 15/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 15/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 15/30 | Treino Loss: 7.9942, Treino Acc: 0.0063 | Val Loss: 6.6544, Val Acc: 0.0281
#   Novo melhor modelo encontrado! Val Loss: 6.6544. Salvando estado...
# Epoch 16/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 16/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 16/30 | Treino Loss: 7.3308, Treino Acc: 0.0126 | Val Loss: 5.8297, Val Acc: 0.0602
#   Novo melhor modelo encontrado! Val Loss: 5.8297. Salvando estado...
# Epoch 17/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 17/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 17/30 | Treino Loss: 6.5609, Treino Acc: 0.0241 | Val Loss: 5.1711, Val Acc: 0.0922
#   Novo melhor modelo encontrado! Val Loss: 5.1711. Salvando estado...
# Epoch 18/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 18/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 18/30 | Treino Loss: 6.0968, Treino Acc: 0.0470 | Val Loss: 4.5239, Val Acc: 0.1508
#   Novo melhor modelo encontrado! Val Loss: 4.5239. Salvando estado...
# Epoch 19/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 19/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 19/30 | Treino Loss: 5.4072, Treino Acc: 0.0647 | Val Loss: 3.9256, Val Acc: 0.1938
#   Novo melhor modelo encontrado! Val Loss: 3.9256. Salvando estado...
# Epoch 20/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 20/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 20/30 | Treino Loss: 4.8579, Treino Acc: 0.1140 | Val Loss: 3.3472, Val Acc: 0.2727
#   Novo melhor modelo encontrado! Val Loss: 3.3472. Salvando estado...
# Epoch 21/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 21/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 21/30 | Treino Loss: 4.3347, Treino Acc: 0.1682 | Val Loss: 2.8675, Val Acc: 0.3789
#   Novo melhor modelo encontrado! Val Loss: 2.8675. Salvando estado...
# Epoch 22/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 22/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 22/30 | Treino Loss: 3.8452, Treino Acc: 0.2332 | Val Loss: 2.3978, Val Acc: 0.5250
#   Novo melhor modelo encontrado! Val Loss: 2.3978. Salvando estado...
# Epoch 23/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 23/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 23/30 | Treino Loss: 3.5066, Treino Acc: 0.3020 | Val Loss: 1.9962, Val Acc: 0.5984
#   Novo melhor modelo encontrado! Val Loss: 1.9962. Salvando estado...
# Epoch 24/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 24/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 24/30 | Treino Loss: 3.0046, Treino Acc: 0.4117 | Val Loss: 1.5745, Val Acc: 0.7125
#   Novo melhor modelo encontrado! Val Loss: 1.5745. Salvando estado...
# Epoch 25/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 25/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 25/30 | Treino Loss: 2.6258, Treino Acc: 0.4986 | Val Loss: 1.2489, Val Acc: 0.7750
#   Novo melhor modelo encontrado! Val Loss: 1.2489. Salvando estado...
# Epoch 26/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 26/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 26/30 | Treino Loss: 2.1191, Treino Acc: 0.6039 | Val Loss: 1.0324, Val Acc: 0.8508
#   Novo melhor modelo encontrado! Val Loss: 1.0324. Salvando estado...
# Epoch 27/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 27/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 27/30 | Treino Loss: 2.0061, Treino Acc: 0.6407 | Val Loss: 0.8751, Val Acc: 0.8508
#   Novo melhor modelo encontrado! Val Loss: 0.8751. Salvando estado...
# Epoch 28/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 28/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 28/30 | Treino Loss: 1.7138, Treino Acc: 0.6898 | Val Loss: 0.5605, Val Acc: 0.9172
#   Novo melhor modelo encontrado! Val Loss: 0.5605. Salvando estado...
# Epoch 29/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 29/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 29/30 | Treino Loss: 1.4819, Treino Acc: 0.7534 | Val Loss: 0.6311, Val Acc: 0.8820
# Epoch 30/30 [Treino]:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 30/30 [Avaliação]:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 30/30 | Treino Loss: 1.2385, Treino Acc: 0.7985 | Val Loss: 0.3977, Val Acc: 0.9289
#   Novo melhor modelo encontrado! Val Loss: 0.3977. Salvando estado...
#
# Tempo total de treinamento: 9379.961 segundos
# ✅ Treinamento concluído. O melhor estado do modelo foi salvo na memória.
# Melhor modelo salvo em 'scface_best_model.pth'

# %% [markdown]
# # 5. Avaliação

# %% [markdown]
# ## 5.1 Funções auxiliares

# %%
def extract_embeddings_fn(dataloader, model, device):
  """Função responsável por extrair os embeddings de imagens

  Args:
    dataloader (torch.utils.data.Dataloader): Dataloader que contém os dados
    sobre as imagens.
    model (torch.nn.Module): Modelo que gera os embeddings a partir das imagens.
    device (torch.device): Dispositivo no qual as inferências serão executadas.
    Sendo 'cpu' ou 'cuda'

  Returns:
    tuple (np.ndarray, np.darray, list[str]):
      - embeddings (np.ndarray): Lista de embeddings normalizados.
      - labels (np.ndarray): Lista com os rótulos das amostras.
      - paths (list[str]]): Lista com os caminhos originais das imagens.

  """

  model.eval()

  embeddings_list, labels_list, paths_list = [], [], []

  with torch.inference_mode():
    for imgs, labels, paths in tqdm(dataloader, desc="Extraindo embeddings"):
      # Pula batches vazios se o collate_fn filtrou tudo
      if imgs is None:
        continue

      imgs = imgs.to(device)

      embeddings_raw = model(imgs)

      # Normalização L2 explícita dos embeddings
      embeddings = F.normalize(embeddings_raw, p=2, dim=1)

      embeddings_list.append(embeddings.cpu().numpy())

      labels_list.extend(labels.cpu().numpy())

      paths_list.extend(list(paths))

  return np.vstack(embeddings_list), np.array(labels_list), list(paths_list)

# %%
def evaluate_full_metrics(gallery_embeds,
                          gallery_lbls,
                          probe_embeds_full,
                          probe_lbls_full,
                          k_ranks=[1, 5, 10, 20]):
  """
  Calcula as métricas completas relacionadas ao reconhecimento facial.
  Obtém: Rank-k, Acurácia, Precisão, Recall e F1-Score.

  Args:
    gallery_embeds (np.ndarray): Embeddings da galeria.
    gallery_lbls (np.ndarray): Rótulos da galeria.
    probe_embeds_full (np.ndarray): Embeddings das imagens de consulta.
    probe_lbls_full (np.ndarray): Rótulos das imagens de consulta.
    k_ranks (list[int], opcional): Lista de valores k para cálculo do
    Rank-k (padrão: [1, 5, 10, 20]).

  Returns:
    dict: Dicionário com as chaves:
      - `'rank_accuracies'` (dict): Acurácia para cada k em `k_ranks`.
      - `'accuracy'` (float): Acurácia global para Rank-1.
      - `'precision'` (float): Precisão ponderada para Rank-1.
      - `'recall'` (float): Recall ponderado para Rank-1.
      - `'f1_score'` (float): F1-score ponderado para Rank-1.

  """

  num_probes_total = len(probe_lbls_full)

  correct_at_k = {k: 0 for k in k_ranks}

  # Lista para guardar todas as predições de Rank-1
  all_rank1_predictions = []

  print("Iniciando avaliação final...")

  distances = cosine_similarity(probe_embeds_full, gallery_embeds)

  sorted_pred_indices = np.argsort(-distances, axis=1)

  # Itera sobre cada sonda para calcular o Rank-k e coletar a predição Rank-1
  for i in range(num_probes_total):
    true_probe_label = probe_lbls_full[i]

    # Coleta a predição de Rank-1 para as métricas de classificação
    rank1_pred_label = gallery_lbls[sorted_pred_indices[i, 0]]

    all_rank1_predictions.append(rank1_pred_label)

    # Lógica para o Rank-k
    sorted_predicted_labels = gallery_lbls[sorted_pred_indices[i]]

    matches = np.where(sorted_predicted_labels == true_probe_label)[0]

    if len(matches) > 0:
      first_match_rank = matches[0] + 1

      for k in k_ranks:
        if first_match_rank <= k:
          correct_at_k[k] += 1

  print("Processamento concluído.")

  # Cálculo das Métricas

  # Rank-k
  rank_accuracies = {k: count / num_probes_total for k, count in correct_at_k.items()}

  # Métricas de Classificação (baseadas nas predições de Rank-1)
  y_true = probe_lbls_full
  y_pred = np.array(all_rank1_predictions)

  accuracy = accuracy_score(y_true, y_pred)

  precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)

  recall = recall_score(y_true, y_pred, average='weighted')

  f1 = f1_score(y_true, y_pred, average='weighted')

  # Organiza todos os resultados em um único dicionário
  final_results = {
      'rank_accuracies': rank_accuracies,
      'accuracy': accuracy,
      'precision': precision,
      'recall': recall,
      'f1_score': f1
  }

  return final_results

# %%
# Preparar o modelo e os dataloaders para avaliação
print("Preparando para a avaliação final...")

final_model = FaceRecognitionModelWithArcFace(num_classes=NUM_SCFACE_CLASSES).to(device)

final_model.load_state_dict(torch.load('scface_best_model.pth',
                                       map_location=device,
                                       weights_only=True))

model_for_embeddings = final_model.backbone

model_for_embeddings.eval()
# Out:
# Preparando para a avaliação final...
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=8631, bias=True)
# )

# %% [markdown]
# ## 5.2 Execução da avaliação

# %%
# 1. Extraindo embeddings
print("\nExtraindo embeddings da galeria e sondas do Scface...")

gallery_embeddings, gallery_labels, gallery_paths = extract_embeddings_fn(gallery_loader_for_eval, model_for_embeddings, device)

probe_embeddings, probe_labels, probe_paths = extract_embeddings_fn(probe_loader, model_for_embeddings, device)
# Out:
# Extraindo embeddings da galeria e sondas do Scface...
# Extraindo embeddings:   0%|          | 0/37 [00:00<?, ?it/s]
# Extraindo embeddings:   0%|          | 0/88 [00:00<?, ?it/s]

# %%
# 2. Avaliando performance
print("\nCalculando métricas de performance...")

final_metrics = evaluate_full_metrics(
    gallery_embeds=gallery_embeddings,
    gallery_lbls=gallery_labels,
    probe_embeds_full=probe_embeddings,
    probe_lbls_full=probe_labels
)
# Out:
# Calculando métricas de performance...
# Iniciando avaliação final...
# Processamento concluído.

# %%
# Imprmindo Rank-k
print("\nMétricas de Identificação (Rank-k):")

for k, acc in final_metrics['rank_accuracies'].items():
  print(f"  - Rank-{k} Accuracy: {acc * 100:.2f}%")

# Imprimindo Métricas de Classificação
print("\nMétricas de Classificação (baseadas no Rank-1):")
print(f"  - Acurácia: {final_metrics['accuracy'] * 100:.2f}%")
print(f"  - Precisão (Ponderada): {final_metrics['precision']:.4f}")
print(f"  - Recall (Ponderado):   {final_metrics['recall']:.4f}")
print(f"  - F1-Score (Ponderado): {final_metrics['f1_score']:.4f}")
# Out:
# Métricas de Identificação (Rank-k):
#   - Rank-1 Accuracy: 52.16%
#   - Rank-5 Accuracy: 55.85%
#   - Rank-10 Accuracy: 62.24%
#   - Rank-20 Accuracy: 69.62%
#
# Métricas de Classificação (baseadas no Rank-1):
#   - Acurácia: 52.16%
#   - Precisão (Ponderada): 0.6092
#   - Recall (Ponderado):   0.5216
#   - F1-Score (Ponderado): 0.5197

# %% [markdown]
# ## 5.3 Verificação do tempo de inferência

# %% [markdown]
# ### 5.3.1 Imagem Única

# %%
def measure_single_image_inference_time(model,
                                        device,
                                        num_runs=100,
                                        num_warmup=10):
  """
  Mede o tempo de inferência para uma única imagem usando um modelo,
  incluindo o cálculo do intervalo de confiança de 95%.

  Args:
    model (torch.nn.Module): Modelo Pytorch a ser avaliado.
    device (torch.device): Dispositivo no qual o modelo será executado.
    num_runs (int): Número de inferências (padrão:100)
    num_warmpu (int): Número de inferências de aquecimento (padrão:10)

  Returns:
    mean_time (float): Tempo médio de inferência para uma imagem.
    std_dev (float): Desvio padrão do mean_time.
  """
  model.eval()

  # Cria uma imagem de entrada de exemplo com o tamanho correto
  dummy_image = torch.randn(1, 3, IMG_SIZE, IMG_SIZE).to(device)

  timings = []

  print(f"--- Iniciando medição de inferência para imagem única ---")
  print(f"Executando {num_warmup} passadas de aquecimento (warm-up)...")

  # 1. Aquecimento (Warm-up)
  with torch.inference_mode():
    for warm_up in range(num_warmup):
      warm_up = model(dummy_image)

  # Garante que todas as operações de aquecimento terminaram
  # antes de começar a medir
  if device == 'cuda':
    torch.cuda.synchronize()

  print(f"Executando {num_runs} passadas cronometradas...")

  # 2. Medição
  with torch.inference_mode():
    for i in range(num_runs):
        if device == 'cuda':
          torch.cuda.synchronize()

        start_time = time.perf_counter()

        runs = model(dummy_image)

        if device == 'cuda':
          torch.cuda.synchronize()

        end_time = time.perf_counter()

        # Convertendo para milissegundos (ms)
        timings.append((end_time - start_time) * 1000)

  # 3. Cálculo das estatísticas
  mean_time = np.mean(timings)
  std_dev = np.std(timings)

  # Cálculo do intervalo de confiança de 95%
  confidence = 0.95
  n = len(timings)
  se = std_dev / np.sqrt(n) # Erro padrão da média
  # Usamos a distribuição-t pois temos uma amostra finita
  h = se * stats.t.ppf((1 + confidence) / 2., n - 1)

  confidence_interval_lower = mean_time - h
  confidence_interval_upper = mean_time + h

  print("\n--- Resultados (Imagem Única) ---")
  print(f"Tempo médio de inferência: {mean_time:.2f} ms")
  print(f"Desvio padrão: {std_dev:.2f} ms")
  print(f"Intervalo de Confiança (95%): [{confidence_interval_lower:.2f} ms, {confidence_interval_upper:.2f} ms]")

  return mean_time, std_dev

# %% [markdown]
# ### 5.3.2 Várias imagens (Throughput)

# %%
def measure_batch_inference_throughput(model, dataloader, device):
  """
  Mede o tempo total para processar um dataloader e calcula
  a vazão (imagens/segundo) de um modelo.

  Args:
    model (torch.nn.Module): Modelo Pytorch a ser avaliado.
    dataloader (torch.utils.data.Dataloader): Dataloader que contém os dados
    sobre as imagens.
    device (torch.device): Dispositivo no qual o modelo será executado.

  Returns:
    images_per_second (images_per_second): Quantidade média de imagens processa
    das por segundo.
  """

  model.eval()

  total_images = len(dataloader.dataset)

  print(f"\n--- Iniciando medição de throughput em {total_images} imagens ---")

  # Aquecimento com o primeiro batch
  try:
    first_batch, x, y = next(iter(dataloader))

    with torch.inference_mode():
      warm_up = model(first_batch.to(device))

    if device == 'cuda':
      torch.cuda.synchronize()

    print("Aquecimento concluído.")
  except StopIteration:
    print("DataLoader está vazio. Não é possível medir.")

    return

  # Medição do tempo total
  start_time = time.perf_counter()

  with torch.inference_mode():
    for images, x, y in tqdm(dataloader, desc="Processando batches"):
      if images is not None:
        runs = model(images.to(device))

  if device == 'cuda':
    torch.cuda.synchronize()

  end_time = time.perf_counter()

  total_time = end_time - start_time
  images_per_second = total_images / total_time
  time_per_image = (total_time / total_images) * 1000

  print("\n--- Resultados (Várias Imagens) ---")
  print(f"Tempo total para processar {total_images} imagens: {total_time:.2f} segundos")
  print(f"Throughput (Vazão): {images_per_second:.2f} imagens por segundo")
  print(f"Tempo médio por imagem em batch: {time_per_image:.2f} ms")

  return images_per_second

# %%
if 'model_for_embeddings' in locals():
  measure_single_image_inference_time(model_for_embeddings, device)
else:
  print("O seu modelo não foi declarado, tente novamente!")
# Out:
# --- Iniciando medição de inferência para imagem única ---
# Executando 10 passadas de aquecimento (warm-up)...
# Executando 100 passadas cronometradas...
#
# --- Resultados (Imagem Única) ---
# Tempo médio de inferência: 18.58 ms
# Desvio padrão: 0.19 ms
# Intervalo de Confiança (95%): [18.54 ms, 18.62 ms]

# %%
if 'probe_loader' in locals():
  measure_batch_inference_throughput(model_for_embeddings, probe_loader, device)
else:
  print("O seu Dataloader de probes não foi inicializado, tente novamente!")
# Out:
# --- Iniciando medição de throughput em 2800 imagens ---
# Aquecimento concluído.
# Processando batches:   0%|          | 0/88 [00:00<?, ?it/s]
# --- Resultados (Várias Imagens) ---
# Tempo total para processar 2800 imagens: 100.73 segundos
# Throughput (Vazão): 27.80 imagens por segundo
# Tempo médio por imagem em batch: 35.97 ms
